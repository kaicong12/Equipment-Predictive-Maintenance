# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import warnings
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import class_weight, shuffle
from sklearn.model_selection import train_test_split


import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, Embedding, concatenate, Reshape, Flatten, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

warnings.filterwarnings("ignore")
BATCH_SIZE = 32
EPOCHS = 300
ec = LabelEncoder() # encode the categorical status
sc = StandardScaler() # scale the whole dataset to make the model learn faster

class status_LSTM:
    def __init__(self, eq_id, hour_horizontal, hour_vertical):
        self.eq_id = eq_id
        self.status_table = self.query_status()
        self.hour_horizontal = hour_horizontal
        self.hour_vertical = hour_vertical
        
        self.start_date = self.status_table.iloc[0]["TIMESTAMP_START"].date() + timedelta(days=1) # add one day to make it start from 00:00:00
        self.end_date = self.status_table.iloc[len(self.status_table)-1]["TIMESTAMP_START"].date()
        self.important_state_name = ["Break down Maintenance", "Utility Problem", "Maintenance", "IT Problem", \
                                    "Waiting For Spares", "MOTOR ERROR", "Half Yearly PM", "IT Maintenance", \
                                    "Machine Failure", "HANG UP", "Waiting For Repair", "BAD WEDGE FORM", "INDEXER PROBLEM",\
                                    "PC Buyoff Failed", "SHORT TAIL", "WIRE BREAK"]
        
        self.timeframe_table = self.generate_time(self.start_date.strftime("%d/%m/%Y"), self.end_date.strftime("%d/%m/%Y"), \
                                                  self.hour_horizontal, self.hour_vertical)

        self.impt_state_seq, self.impt_duration_seq = self.status_sequence(self.timeframe_table, self.status_table, important="YES")
        self.major_down_arr = self.major_down(self.timeframe_table, self.status_table, 6, 3600)
         
    def query_status(self):
            try:
                oracle_string = "oracle+cx_oracle://{username}:{password}@{hostname}:{port}/{database}"
                engine = create_engine(
                    oracle_string.format(
                        username = 'TFM4CEBERUS',
                        password = 'TFM4CEBERUS',
                        hostname = 'ome-db.bth.infineon.com',
                        port = '1538',
                        database = 'ome'
                        )
                    )
            except Exception as e:
                print(str(e))

            query = f"""select EQ_ID, TIMESTAMP_START, TIMESTAMP_END, DURATION, STATE_NAME, LEVEL3_NAME, LEVEL3 
                    from (SELECT
                      eq.eq_id, eq.name, eq.eq_type_ident
                    , data.timestamp_start,data.timestamp_end
                    , ROUND((data.timestamp_end - data.timestamp_start)*24*60*60,0) AS Duration
                    , data.tr25_3_status,data.tr25_4_status,data.tr25_5_status,data.eq_status
                    , level5s.state_name
                    , level5.state_name Level5_Name, level5.state_sign Level5
                    , level4.state_name Level4_Name, level4.state_sign Level4
                    , level3.state_name Level3_Name, level3.state_sign Level3
                    ,mh.device
                    ,mh.package,
                    mh.lotid as lot,
                    mh.product,
                    mh.operation

                    FROM OMEDATA.EQUIPMENT_STATE_HISTORY data
                    , OMEADMIN.EQUIPMENT_INSTANCES eq
                    , V_EQ_STATES level5s
                    , OMEADMIN.DEF_STANDARD_STATEMODEL level5
                    , OMEADMIN.DEF_STANDARD_STATEMODEL level4
                    , OMEADMIN.DEF_STANDARD_STATEMODEL level3
                    , OMEDATA.METAKEY_HISTORY mh

                    WHERE data.eq_ident  = eq.eq_ident
                    AND  data.eq_status = level5s.state_ident(+)
                    AND level5.state_ident = data.tr25_5_status
                    AND level4.state_ident = data.tr25_4_status
                    AND level3.state_ident = data.tr25_3_status
                    AND  data.metakey_ident =mh.ident(+)
                    and data.timestamp_start > sysdate - 1050)
                    where eq_id = '{self.eq_id}'
                    ORDER BY TIMESTAMP_START"""

            status = pd.read_sql(query, engine)
            status.columns = map(lambda x: str(x).upper(), status.columns) 

            return status

    def generate_time(self, start_date:str, end_date:str, hours_row:int, hour:int):
        start = datetime.strptime(start_date, '%d/%m/%Y')
        end = datetime.strptime(end_date, '%d/%m/%Y')

        dates = []
        while start+timedelta(hours=hours_row)<=end:
            row = [start, start+timedelta(hours=hours_row)]
            dates.append(row)
            start += timedelta(hours=hour)

        return pd.DataFrame(dates, columns=['TIMESTAMP_START', 'TIMESTAMP_END'])


    def major_down(self, input_df, status_table, hour, threshold):
            hour = pd.Timedelta(hours=hour)
            major_down = []
            
            # timeframe table must be a subset of the status table to correctly determine major down
            if status_table.iloc[0]["TIMESTAMP_START"] >= input_df.iloc[0]["TIMESTAMP_START"]:
                raise Exception("Timeframe table must be a subset of the status table")
            if status_table.iloc[len(status_table)-1]["TIMESTAMP_START"] <= input_df.iloc[len(input_df)-1]["TIMESTAMP_START"]:
                raise Exception("Timeframe table must be a subset of the status table")

            for idx, row in input_df.iterrows():
                start = row['TIMESTAMP_END']
                end = start+hour
                frame = status_table[(status_table['TIMESTAMP_START']>start) & (status_table['TIMESTAMP_START']<end)]
                UD = frame.loc[frame['LEVEL3']=='UDT']

                if len(UD) == 0: #no record within this 6 hours:
                    major_down.append(0)
                else:
                    time_diff = (UD['TIMESTAMP_END']-UD['TIMESTAMP_START']).dt.seconds
                    if any(time_diff>threshold):
                        major_down.append(1)
                    else:
                        major_down.append(0)
            return major_down

    def status_sequence(self, input_table, status_table, important=None):
        status_seq = []
        duration_seq = []
        
        # validation check
        if status_table.iloc[0]["TIMESTAMP_START"] > input_table.iloc[0]["TIMESTAMP_START"]:
            raise Exception("Timeframe table must be a subset of the status table")
        if status_table.iloc[len(status_table)-1]["TIMESTAMP_START"] <= input_table.iloc[len(input_table)-1]["TIMESTAMP_START"]:
                raise Exception("Timeframe table must be a subset of the status table")
        
        for idx, row in input_table.iterrows():
            start = row["TIMESTAMP_START"]
            end = row["TIMESTAMP_END"]
            
            condition = (status_table["TIMESTAMP_START"]>=start) & (status_table["TIMESTAMP_START"]<=end)
            if important == "YES":
                condition = (status_table["TIMESTAMP_START"]>=start) & (status_table["TIMESTAMP_START"]<=end) & \
                                (status_table.STATE_NAME.isin(self.important_state_name))
            
            table = status_table[condition]
            status_seq.append(table["STATE_NAME"].values)
            duration_seq.append(table["DURATION"].values)

        return status_seq, duration_seq

    def preprocess(self, status_seq, duration_seq):
        X_seq = []
        for ele, dur in zip(status_seq, duration_seq):
            tmp = []
            for idx in range(len(ele)):
                tmp.append([ele[idx], int(dur[idx])])
            X_seq.append(tmp)
        return np.array(X_seq)

# %% [markdown]
# # Training without excluding unimportant state name
# ##### Skipped for now, training took too long (one epoch 30 mins!) as the padded time stamp contains too many status values

# %%
# hour = 24
# start = datetime.now()
# print(f"Training by looking back {hour} hours of alarm data")
# wba124 = status_LSTM("WBA124", hour, 3)

# # pad the alarm to train on LSTM
# unpadded_status_arr = wba124.encoded_status_seq
# unpadded_duration_arr = wba124.duration_seq

# padded_status_arr = np.zeros([len(unpadded_status_arr),len(max(unpadded_status_arr,key = lambda x: len(x)))])
# padded_duration_arr = np.zeros([len(unpadded_duration_arr),len(max(unpadded_duration_arr,key = lambda x: len(x)))])
# for i,j in enumerate(unpadded_status_arr):
#     padded_status_arr[i][0:len(j)] = j
#     padded_duration_arr[i][0:len(j)] = unpadded_duration_arr[i]

# # standard scale for the model to learn faster
# padded_X_seq = wba124.preprocess(padded_status_arr, padded_duration_arr)
# for i in range(padded_X_seq.shape[1]):
#     padded_X_seq[:, i, :] = sc.fit_transform(padded_X_seq[:, i, :])

# #train_val_test split
# val_percentage = 0.2
# test_percentage = 0.1

# test_index = int(len(padded_X_seq) * (1-test_percentage))
# val_index = int(len(padded_X_seq) * (1- val_percentage - test_percentage))

# X_train_seq, X_val_seq, X_test_seq = padded_X_seq[:val_index], padded_X_seq[val_index:test_index], padded_X_seq[test_index:]
# y_train_seq, y_val_seq, y_test_seq = wba124.major_down_arr[:val_index], wba124.major_down_arr[val_index:test_index], wba124.major_down_arr[test_index:]

# X_train_seq = X_train_seq.reshape(X_train_seq.shape[0], X_train_seq.shape[1], 2)
# X_val_seq = X_val_seq.reshape(X_val_seq.shape[0], X_val_seq.shape[1], 2)
# X_test_seq = X_test_seq.reshape(X_test_seq.shape[0], X_test_seq.shape[1], 2)

# %%
# ## Training took too long, one epoch 30 MINS!!! ##
# seq_result = {}

# class_weights = class_weight.compute_class_weight('balanced',
#                                              np.unique(y_train_seq),
#                                              y_train_seq)
# class_weights_dict = dict(enumerate(class_weights))

# #need to reinitialize the model because x_train_seq changes in shape
# model = Sequential()
# model.add(LSTM(128, input_shape=(X_train_seq.shape[1:]), return_sequences=True))
# model.add(Dropout(0.5))

# model.add(LSTM(128, input_shape=(X_train_seq.shape[1:])))
# model.add(Dropout(0.5))

# model.add(Dense(32, activation = 'relu'))
# model.add(Dropout(0.2))

# model.add(Dense(2, activation = 'softmax'))

# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# history = model.fit(np.array(X_train_seq), np.array(y_train_seq), 
#                 batch_size=BATCH_SIZE, epochs=EPOCHS, 
#                 validation_data=(np.array(X_val_seq), np.array(y_val_seq)),
#                 class_weight = class_weights_dict)

# evaluate = model.evaluate(np.array(X_test_seq), np.array(y_test_seq)) #loss, mse

# seq_result[hour] = evaluate
# end = datetime.now()
# time = end - start
# print(f"Training took a total of {time.seconds} seconds")

# %% [markdown]
# # Training with only important state name and duration
# ## Padding the sequence with max length

# %%
def compile_and_train(X_train_seq, X_val_seq, X_test_seq, y_train_seq, y_val_seq, y_test_seq):
    """
    Returns the evaluation score for the model
    """
    class_weights = class_weight.compute_class_weight('balanced',
                                             np.unique(y_train_seq),
                                             y_train_seq)
    class_weights_dict = dict(enumerate(class_weights))

    #need to reinitialize the model because x_train_seq changes in shape
    model = Sequential()
    model.add(LSTM(256, input_shape=(X_train_seq.shape[1:]), return_sequences=True))
    model.add(Dropout(0.5))

    model.add(LSTM(256, input_shape=(X_train_seq.shape[1:])))
    model.add(Dropout(0.5))

    model.add(Dense(32, activation = 'relu'))
    model.add(Dropout(0.2))

    model.add(Dense(2, activation = 'softmax'))

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(np.array(X_train_seq), np.array(y_train_seq), 
                    batch_size=BATCH_SIZE, epochs=EPOCHS, 
                    validation_data=(np.array(X_val_seq), np.array(y_val_seq)),
                    class_weight = class_weights_dict)

    evaluate = model.evaluate(np.array(X_test_seq), np.array(y_test_seq)) #loss, mse
    return evaluate

# %%
seq_result = {}
# lookback = [24,48,72,96]

# for hour in lookback:
hour = 12
start = datetime.now()
print(f"Training by looking back {hour} hours of important STATE NAME data")
wba124 = status_LSTM("WBA124", hour, 3)

# pad the alarm to train on LSTM
unpadded_status_arr = wba124.encoded_impt_state_seq
unpadded_duration_arr = wba124.impt_duration_seq

padded_status_arr = np.zeros([len(unpadded_status_arr),len(max(unpadded_status_arr,key = lambda x: len(x)))])
padded_duration_arr = np.zeros([len(unpadded_duration_arr),len(max(unpadded_duration_arr,key = lambda x: len(x)))])
for i,j in enumerate(unpadded_status_arr):
    padded_status_arr[i][0:len(j)] = j
    padded_duration_arr[i][0:len(j)] = unpadded_duration_arr[i]

# standard scale for the model to learn faster
padded_X_seq = wba124.preprocess(padded_status_arr, padded_duration_arr)
for i in range(padded_X_seq.shape[1]):
    padded_X_seq[:, i, :] = sc.fit_transform(padded_X_seq[:, i, :])

#train_val_test split
val_percentage = 0.2
test_percentage = 0.1

test_index = int(len(padded_X_seq) * (1-test_percentage))
val_index = int(len(padded_X_seq) * (1- val_percentage - test_percentage))

X_train_seq, X_val_seq, X_test_seq = padded_X_seq[:val_index], padded_X_seq[val_index:test_index], padded_X_seq[test_index:]
y_train_seq, y_val_seq, y_test_seq = wba124.major_down_arr[:val_index], wba124.major_down_arr[val_index:test_index], wba124.major_down_arr[test_index:]

X_train_seq = X_train_seq.reshape(X_train_seq.shape[0], X_train_seq.shape[1], 2)
X_val_seq = X_val_seq.reshape(X_val_seq.shape[0], X_val_seq.shape[1], 2)
X_test_seq = X_test_seq.reshape(X_test_seq.shape[0], X_test_seq.shape[1], 2)

# train and evaluate the model
evaluate = compile_and_train(X_train_seq, X_val_seq, X_test_seq, y_train_seq, y_val_seq, y_test_seq)

seq_result[hour] = evaluate
end = datetime.now()
time = end - start
print(f"Training took a total of {time.seconds} seconds")
# Out:
# Training by looking back 12 hours of important STATE NAME data
# Epoch 1/100
# 184/184 [==============================] - 311s 2s/step - loss: 0.7231 - accuracy: 0.6478 - val_loss: 0.7749 - val_accuracy: 0.6466
# Epoch 2/100
# 184/184 [==============================] - 306s 2s/step - loss: 0.6856 - accuracy: 0.7147 - val_loss: 0.7434 - val_accuracy: 0.6436
# Epoch 3/100
# 184/184 [==============================] - 308s 2s/step - loss: 0.6854 - accuracy: 0.7670 - val_loss: 0.7929 - val_accuracy: 0.6442
# Epoch 4/100
# 184/184 [==============================] - 302s 2s/step - loss: 0.6791 - accuracy: 0.7599 - val_loss: 0.7272 - val_accuracy: 0.6472
# Epoch 5/100
# 184/184 [==============================] - 305s 2s/step - loss: 0.6819 - accuracy: 0.7747 - val_loss: 0.7005 - val_accuracy: 0.6472
# Epoch 6/100
# 184/184 [==============================] - 305s 2s/step - loss: 0.6775 - accuracy: 0.7858 - val_loss: 0.6901 - val_accuracy: 0.6478
# Epoch 7/100
# 184/184 [==============================] - 304s 2s/step - loss: 0.6778 - accuracy: 0.7924 - val_loss: 0.7236 - val_accuracy: 0.6424
# Epoch 8/100
# 184/184 [==============================] - 310s 2s/step - loss: 0.6755 - accuracy: 0.7912 - val_loss: 0.7798 - val_accuracy: 0.6442
# Epoch 9/100
# 184/184 [==============================] - 306s 2s/step - loss: 0.6777 - accuracy: 0.7914 - val_loss: 0.7351 - val_accuracy: 0.6424
# Epoch 10/100
# 184/184 [==============================] - 306s 2s/step - loss: 0.6779 - accuracy: 0.7919 - val_loss: 0.7181 - val_accuracy: 0.6412
# Epoch 11/100
# 184/184 [==============================] - 303s 2s/step - loss: 0.6786 - accuracy: 0.7878 - val_loss: 0.7162 - val_accuracy: 0.6412
# Epoch 12/100
# 184/184 [==============================] - 302s 2s/step - loss: 0.6769 - accuracy: 0.7921 - val_loss: 0.7514 - val_accuracy: 0.6424
# Epoch 13/100
# 184/184 [==============================] - 303s 2s/step - loss: 0.6771 - accuracy: 0.7796 - val_loss: 0.7612 - val_accuracy: 0.6418
# Epoch 14/100
# 184/184 [==============================] - 310s 2s/step - loss: 0.6747 - accuracy: 0.7941 - val_loss: 0.8133 - val_accuracy: 0.6454
# Epoch 15/100
# 184/184 [==============================] - 315s 2s/step - loss: 0.6757 - accuracy: 0.7921 - val_loss: 0.7874 - val_accuracy: 0.6460
# Epoch 16/100
# 184/184 [==============================] - 315s 2s/step - loss: 0.6755 - accuracy: 0.7917 - val_loss: 0.7184 - val_accuracy: 0.6466
# Epoch 17/100
# 184/184 [==============================] - 321s 2s/step - loss: 0.6774 - accuracy: 0.7946 - val_loss: 0.7233 - val_accuracy: 0.6454
# Epoch 18/100
# 184/184 [==============================] - 319s 2s/step - loss: 0.6746 - accuracy: 0.7939 - val_loss: 0.7481 - val_accuracy: 0.6448
# Epoch 19/100
# 184/184 [==============================] - 319s 2s/step - loss: 0.6778 - accuracy: 0.7921 - val_loss: 0.7066 - val_accuracy: 0.6460
# Epoch 20/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6753 - accuracy: 0.7893 - val_loss: 0.7105 - val_accuracy: 0.6395
# Epoch 21/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6760 - accuracy: 0.7905 - val_loss: 0.7149 - val_accuracy: 0.6460
# Epoch 22/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6785 - accuracy: 0.7914 - val_loss: 0.7548 - val_accuracy: 0.6466
# Epoch 23/100
# 184/184 [==============================] - 316s 2s/step - loss: 0.6753 - accuracy: 0.7929 - val_loss: 0.7534 - val_accuracy: 0.6460
# Epoch 24/100
# 184/184 [==============================] - 320s 2s/step - loss: 0.6748 - accuracy: 0.7926 - val_loss: 0.7213 - val_accuracy: 0.6466
# Epoch 25/100
# 184/184 [==============================] - 320s 2s/step - loss: 0.6769 - accuracy: 0.7936 - val_loss: 0.7397 - val_accuracy: 0.6478
# Epoch 26/100
# 184/184 [==============================] - 316s 2s/step - loss: 0.6769 - accuracy: 0.7917 - val_loss: 0.7261 - val_accuracy: 0.6466
# Epoch 27/100
# 184/184 [==============================] - 315s 2s/step - loss: 0.6785 - accuracy: 0.7979 - val_loss: 0.7102 - val_accuracy: 0.6466
# Epoch 28/100
# 184/184 [==============================] - 319s 2s/step - loss: 0.6782 - accuracy: 0.7926 - val_loss: 0.7370 - val_accuracy: 0.6454
# Epoch 29/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6776 - accuracy: 0.7929 - val_loss: 0.7422 - val_accuracy: 0.6460
# Epoch 30/100
# 184/184 [==============================] - 319s 2s/step - loss: 0.6758 - accuracy: 0.7921 - val_loss: 0.7173 - val_accuracy: 0.6466
# Epoch 31/100
# 184/184 [==============================] - 321s 2s/step - loss: 0.6765 - accuracy: 0.7936 - val_loss: 0.7232 - val_accuracy: 0.6466
# Epoch 32/100
# 184/184 [==============================] - 321s 2s/step - loss: 0.6754 - accuracy: 0.7926 - val_loss: 0.7269 - val_accuracy: 0.6383
# Epoch 33/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6734 - accuracy: 0.7910 - val_loss: 0.7817 - val_accuracy: 0.6430
# Epoch 34/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6775 - accuracy: 0.7931 - val_loss: 0.7323 - val_accuracy: 0.6436
# Epoch 35/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6766 - accuracy: 0.7895 - val_loss: 0.7397 - val_accuracy: 0.6418
# Epoch 36/100
# 184/184 [==============================] - 320s 2s/step - loss: 0.6752 - accuracy: 0.7914 - val_loss: 0.7257 - val_accuracy: 0.6430
# Epoch 37/100
# 184/184 [==============================] - 316s 2s/step - loss: 0.6762 - accuracy: 0.7909 - val_loss: 0.7700 - val_accuracy: 0.6442
# Epoch 38/100
# 184/184 [==============================] - 333s 2s/step - loss: 0.6767 - accuracy: 0.7914 - val_loss: 0.7303 - val_accuracy: 0.6436
# Epoch 39/100
# 184/184 [==============================] - 315s 2s/step - loss: 0.6773 - accuracy: 0.7914 - val_loss: 0.7159 - val_accuracy: 0.6412
# Epoch 40/100
# 184/184 [==============================] - 319s 2s/step - loss: 0.6756 - accuracy: 0.7832 - val_loss: 0.7437 - val_accuracy: 0.6228
# Epoch 41/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6791 - accuracy: 0.7648 - val_loss: 0.7353 - val_accuracy: 0.6180
# Epoch 42/100
# 184/184 [==============================] - 316s 2s/step - loss: 0.6809 - accuracy: 0.7640 - val_loss: 0.7279 - val_accuracy: 0.6198
# Epoch 43/100
# 184/184 [==============================] - 319s 2s/step - loss: 0.6772 - accuracy: 0.7875 - val_loss: 0.7395 - val_accuracy: 0.6472
# Epoch 44/100
# 184/184 [==============================] - 315s 2s/step - loss: 0.6725 - accuracy: 0.8001 - val_loss: 0.7453 - val_accuracy: 0.6478
# Epoch 45/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6745 - accuracy: 0.7994 - val_loss: 0.7290 - val_accuracy: 0.6454
# Epoch 46/100
# 184/184 [==============================] - 314s 2s/step - loss: 0.6742 - accuracy: 0.7968 - val_loss: 0.7212 - val_accuracy: 0.6472
# Epoch 47/100
# 184/184 [==============================] - 312s 2s/step - loss: 0.6725 - accuracy: 0.7982 - val_loss: 0.7317 - val_accuracy: 0.6484
# Epoch 48/100
# 184/184 [==============================] - 315s 2s/step - loss: 0.6751 - accuracy: 0.7968 - val_loss: 0.7145 - val_accuracy: 0.6466
# Epoch 49/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6766 - accuracy: 0.7980 - val_loss: 0.7043 - val_accuracy: 0.6466
# Epoch 50/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6760 - accuracy: 0.7967 - val_loss: 0.7235 - val_accuracy: 0.6472
# Epoch 51/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6746 - accuracy: 0.7972 - val_loss: 0.7067 - val_accuracy: 0.6460
# Epoch 52/100
# 184/184 [==============================] - 316s 2s/step - loss: 0.6762 - accuracy: 0.8009 - val_loss: 0.7208 - val_accuracy: 0.6657
# Epoch 53/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6808 - accuracy: 0.8455 - val_loss: 0.6418 - val_accuracy: 0.8391
# Epoch 54/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6982 - accuracy: 0.8833 - val_loss: 0.6631 - val_accuracy: 0.8391
# Epoch 55/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6939 - accuracy: 0.9033 - val_loss: 0.6757 - val_accuracy: 0.8391
# Epoch 56/100
# 184/184 [==============================] - 314s 2s/step - loss: 0.6941 - accuracy: 0.9017 - val_loss: 0.6834 - val_accuracy: 0.8391
# Epoch 57/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6922 - accuracy: 0.8025 - val_loss: 0.7056 - val_accuracy: 0.1609
# Epoch 58/100
# 184/184 [==============================] - 316s 2s/step - loss: 0.6924 - accuracy: 0.6349 - val_loss: 0.6892 - val_accuracy: 0.8391
# Epoch 59/100
# 184/184 [==============================] - 315s 2s/step - loss: 0.6918 - accuracy: 0.8650 - val_loss: 0.6918 - val_accuracy: 0.8391
# Epoch 60/100
# 184/184 [==============================] - 314s 2s/step - loss: 0.6923 - accuracy: 0.7858 - val_loss: 0.6935 - val_accuracy: 0.1609
# Epoch 61/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6931 - accuracy: 0.3755 - val_loss: 0.6965 - val_accuracy: 0.1609
# Epoch 62/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6924 - accuracy: 0.4361 - val_loss: 0.6959 - val_accuracy: 0.1609
# Epoch 63/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6922 - accuracy: 0.5400 - val_loss: 0.6921 - val_accuracy: 0.8391
# Epoch 64/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6923 - accuracy: 0.5823 - val_loss: 0.6907 - val_accuracy: 0.8391
# Epoch 65/100
# 184/184 [==============================] - 323s 2s/step - loss: 0.6920 - accuracy: 0.2260 - val_loss: 0.6942 - val_accuracy: 0.1609
# Epoch 66/100
# 184/184 [==============================] - 323s 2s/step - loss: 0.6921 - accuracy: 0.4775 - val_loss: 0.6818 - val_accuracy: 0.8391
# Epoch 67/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6928 - accuracy: 0.5988 - val_loss: 0.6925 - val_accuracy: 0.8391
# Epoch 68/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6923 - accuracy: 0.1771 - val_loss: 0.6923 - val_accuracy: 0.8391
# Epoch 69/100
# 184/184 [==============================] - 319s 2s/step - loss: 0.6919 - accuracy: 0.6858 - val_loss: 0.6911 - val_accuracy: 0.8391
# Epoch 70/100
# 184/184 [==============================] - 316s 2s/step - loss: 0.6923 - accuracy: 0.8837 - val_loss: 0.6899 - val_accuracy: 0.8391
# Epoch 71/100
# 184/184 [==============================] - 320s 2s/step - loss: 0.6921 - accuracy: 0.2778 - val_loss: 0.6914 - val_accuracy: 0.8391
# Epoch 72/100
# 184/184 [==============================] - 338s 2s/step - loss: 0.6922 - accuracy: 0.6165 - val_loss: 0.6899 - val_accuracy: 0.8391
# Epoch 73/100
# 184/184 [==============================] - 396s 2s/step - loss: 0.6921 - accuracy: 0.8888 - val_loss: 0.6919 - val_accuracy: 0.8391
# Epoch 74/100
# 184/184 [==============================] - 366s 2s/step - loss: 0.6921 - accuracy: 0.6916 - val_loss: 0.6929 - val_accuracy: 0.8391
# Epoch 75/100
# 184/184 [==============================] - 324s 2s/step - loss: 0.6920 - accuracy: 0.5857 - val_loss: 0.6910 - val_accuracy: 0.8391
# Epoch 76/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6937 - accuracy: 0.4528 - val_loss: 0.6921 - val_accuracy: 0.8391
# Epoch 77/100
# 184/184 [==============================] - 320s 2s/step - loss: 0.6923 - accuracy: 0.8316 - val_loss: 0.6943 - val_accuracy: 0.1609
# Epoch 78/100
# 184/184 [==============================] - 322s 2s/step - loss: 0.6922 - accuracy: 0.5908 - val_loss: 0.6974 - val_accuracy: 0.1609
# Epoch 79/100
# 184/184 [==============================] - 324s 2s/step - loss: 0.6922 - accuracy: 0.1081 - val_loss: 0.6945 - val_accuracy: 0.1609
# Epoch 80/100
# 184/184 [==============================] - 326s 2s/step - loss: 0.6921 - accuracy: 0.2371 - val_loss: 0.6936 - val_accuracy: 0.1609
# Epoch 81/100
# 184/184 [==============================] - 323s 2s/step - loss: 0.6921 - accuracy: 0.7655 - val_loss: 0.6923 - val_accuracy: 0.8391
# Epoch 82/100
# 184/184 [==============================] - 321s 2s/step - loss: 0.6920 - accuracy: 0.8290 - val_loss: 0.6947 - val_accuracy: 0.1609
# Epoch 83/100
# 184/184 [==============================] - 320s 2s/step - loss: 0.6921 - accuracy: 0.1449 - val_loss: 0.6939 - val_accuracy: 0.1609
# Epoch 84/100
# 184/184 [==============================] - 322s 2s/step - loss: 0.6921 - accuracy: 0.2130 - val_loss: 0.6950 - val_accuracy: 0.1609
# Epoch 85/100
# 184/184 [==============================] - 324s 2s/step - loss: 0.6921 - accuracy: 0.7325 - val_loss: 0.6943 - val_accuracy: 0.1609
# Epoch 86/100
# 184/184 [==============================] - 324s 2s/step - loss: 0.6920 - accuracy: 0.5879 - val_loss: 0.6940 - val_accuracy: 0.1609
# Epoch 87/100
# 184/184 [==============================] - 321s 2s/step - loss: 0.6924 - accuracy: 0.6240 - val_loss: 0.6923 - val_accuracy: 0.8391
# Epoch 88/100
# 184/184 [==============================] - 326s 2s/step - loss: 0.6922 - accuracy: 0.6008 - val_loss: 0.6943 - val_accuracy: 0.1609
# Epoch 89/100
# 184/184 [==============================] - 324s 2s/step - loss: 0.6921 - accuracy: 0.2253 - val_loss: 0.6949 - val_accuracy: 0.1609
# Epoch 90/100
# 184/184 [==============================] - 320s 2s/step - loss: 0.6922 - accuracy: 0.8135 - val_loss: 0.6941 - val_accuracy: 0.1609
# Epoch 91/100
# 184/184 [==============================] - 318s 2s/step - loss: 0.6920 - accuracy: 0.1042 - val_loss: 0.6938 - val_accuracy: 0.1609
# Epoch 92/100
# 184/184 [==============================] - 323s 2s/step - loss: 0.6919 - accuracy: 0.7718 - val_loss: 0.6934 - val_accuracy: 0.1609
# Epoch 93/100
# 184/184 [==============================] - 322s 2s/step - loss: 0.6928 - accuracy: 0.7723 - val_loss: 0.6941 - val_accuracy: 0.1609
# Epoch 94/100
# 184/184 [==============================] - 322s 2s/step - loss: 0.6925 - accuracy: 0.4327 - val_loss: 0.6907 - val_accuracy: 0.8391
# Epoch 95/100
# 184/184 [==============================] - 323s 2s/step - loss: 0.6926 - accuracy: 0.2267 - val_loss: 0.6971 - val_accuracy: 0.1609
# Epoch 96/100
# 184/184 [==============================] - 323s 2s/step - loss: 0.6922 - accuracy: 0.1303 - val_loss: 0.6954 - val_accuracy: 0.1609
# Epoch 97/100
# 184/184 [==============================] - 325s 2s/step - loss: 0.6922 - accuracy: 0.7142 - val_loss: 0.6948 - val_accuracy: 0.1609
# Epoch 98/100
# 184/184 [==============================] - 325s 2s/step - loss: 0.6926 - accuracy: 0.3822 - val_loss: 0.6925 - val_accuracy: 0.8391
# Epoch 99/100
# 184/184 [==============================] - 320s 2s/step - loss: 0.6929 - accuracy: 0.3389 - val_loss: 0.6991 - val_accuracy: 0.1609
# Epoch 100/100
# 184/184 [==============================] - 317s 2s/step - loss: 0.6926 - accuracy: 0.1705 - val_loss: 0.6958 - val_accuracy: 0.1609
# 27/27 [==============================] - 10s 361ms/step - loss: 0.6965 - accuracy: 0.0751
# Training took a total of 32005 seconds

# %%
seq_result
# Out:
# {12: [0.6964600682258606, 0.07508939504623413]}

# %%
X_train_seq.shape # this is padded with the max length of all sequences
# Out:
# (5872, 127, 2)

# %% [markdown]
# # Training with only important state name and duration
# ## Padding the sequence with the average length
# #### https://towardsdatascience.com/using-tensorflow-ragged-tensors-2af07849a7bd
# #### Apparently can also greatly help boost accracy

# %%
seq_result = {}

lookback = [12,24,48,72,96]
for hour in lookback:
    start = datetime.now()
    print(f"Training by looking back {hour} hours of important STATE NAME data")
    wba124 = status_LSTM("WBA124", hour, 3)

    # pad the alarm to train on LSTM
    unpadded_status_arr = wba124.encoded_impt_state_seq
    unpadded_duration_arr = wba124.impt_duration_seq

    mean_length = int(np.mean([len(x) for x in unpadded_status_arr]))
    padded_status_arr = np.zeros([len(unpadded_status_arr), mean_length])
    padded_duration_arr = np.zeros([len(unpadded_duration_arr), mean_length])

    for i,j in enumerate(unpadded_status_arr):
        padded_status_arr[i][0:len(j)] = j[:mean_length]
        padded_duration_arr[i][0:len(unpadded_duration_arr[i])] = unpadded_duration_arr[i][:mean_length]

    # standard scale for the model to learn faster
    padded_X_seq = wba124.preprocess(padded_status_arr, padded_duration_arr)
    for i in range(padded_X_seq.shape[1]):
        padded_X_seq[:, i, :] = sc.fit_transform(padded_X_seq[:, i, :])

    #train_val_test split
    val_percentage = 0.2
    test_percentage = 0.1

    test_index = int(len(padded_X_seq) * (1-test_percentage))
    val_index = int(len(padded_X_seq) * (1- val_percentage - test_percentage))

    X_train_seq, X_val_seq, X_test_seq = padded_X_seq[:val_index], padded_X_seq[val_index:test_index], padded_X_seq[test_index:]
    y_train_seq, y_val_seq, y_test_seq = wba124.major_down_arr[:val_index], wba124.major_down_arr[val_index:test_index], wba124.major_down_arr[test_index:]

    X_train_seq = X_train_seq.reshape(X_train_seq.shape[0], X_train_seq.shape[1], 2)
    X_val_seq = X_val_seq.reshape(X_val_seq.shape[0], X_val_seq.shape[1], 2)
    X_test_seq = X_test_seq.reshape(X_test_seq.shape[0], X_test_seq.shape[1], 2)
    
    # train and evaluate the model
    evaluate = compile_and_train(X_train_seq, X_val_seq, X_test_seq, y_train_seq, y_val_seq, y_test_seq)

    seq_result[hour, mean_length] = evaluate
    end = datetime.now()
    time = end - start
    print(f"Training took a total of {time.seconds} seconds")
# Out:
# Training by looking back 12 hours of important STATE NAME data
# Epoch 1/100
# 184/184 [==============================] - 7s 24ms/step - loss: 0.6573 - accuracy: 0.6008 - val_loss: 0.6721 - val_accuracy: 0.5317
# Epoch 2/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6587 - accuracy: 0.6308 - val_loss: 0.7247 - val_accuracy: 0.5287
# Epoch 3/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6578 - accuracy: 0.6294 - val_loss: 0.7386 - val_accuracy: 0.5179
# Epoch 4/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6577 - accuracy: 0.6369 - val_loss: 0.6469 - val_accuracy: 0.5329
# Epoch 5/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6568 - accuracy: 0.6388 - val_loss: 0.6866 - val_accuracy: 0.5400
# Epoch 6/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6561 - accuracy: 0.6448 - val_loss: 0.7881 - val_accuracy: 0.4671
# Epoch 7/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6570 - accuracy: 0.6284 - val_loss: 0.7811 - val_accuracy: 0.5048
# Epoch 8/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6562 - accuracy: 0.6518 - val_loss: 0.6804 - val_accuracy: 0.5585
# Epoch 9/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6543 - accuracy: 0.6571 - val_loss: 0.7157 - val_accuracy: 0.5281
# Epoch 10/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6501 - accuracy: 0.6567 - val_loss: 0.7952 - val_accuracy: 0.5018
# Epoch 11/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6568 - accuracy: 0.6526 - val_loss: 0.6695 - val_accuracy: 0.5914
# Epoch 12/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6511 - accuracy: 0.6705 - val_loss: 0.6972 - val_accuracy: 0.5388
# Epoch 13/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6519 - accuracy: 0.6617 - val_loss: 0.6488 - val_accuracy: 0.5914
# Epoch 14/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6519 - accuracy: 0.6405 - val_loss: 0.7458 - val_accuracy: 0.5299
# Epoch 15/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6524 - accuracy: 0.6683 - val_loss: 0.6917 - val_accuracy: 0.5376
# Epoch 16/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6526 - accuracy: 0.6478 - val_loss: 0.6309 - val_accuracy: 0.5944
# Epoch 17/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6529 - accuracy: 0.6547 - val_loss: 0.6912 - val_accuracy: 0.5341
# Epoch 18/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6462 - accuracy: 0.6514 - val_loss: 0.7621 - val_accuracy: 0.5000
# Epoch 19/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6546 - accuracy: 0.6528 - val_loss: 0.7202 - val_accuracy: 0.5364
# Epoch 20/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6488 - accuracy: 0.6629 - val_loss: 0.8265 - val_accuracy: 0.5024
# Epoch 21/100
# 184/184 [==============================] - 4s 20ms/step - loss: 0.6490 - accuracy: 0.6617 - val_loss: 0.7111 - val_accuracy: 0.5442
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6558 - accuracy: 0.6348
# Training took a total of 214 seconds
# Training by looking back 24 hours of important STATE NAME data
# Epoch 1/100
# 184/184 [==============================] - 10s 41ms/step - loss: 0.6737 - accuracy: 0.5688 - val_loss: 0.7781 - val_accuracy: 0.4421
# Epoch 2/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6652 - accuracy: 0.5852 - val_loss: 0.7464 - val_accuracy: 0.4528
# Epoch 3/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6682 - accuracy: 0.5116 - val_loss: 0.6935 - val_accuracy: 0.4869
# Epoch 4/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6669 - accuracy: 0.6005 - val_loss: 0.6779 - val_accuracy: 0.5090
# Epoch 5/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6642 - accuracy: 0.5941 - val_loss: 0.7293 - val_accuracy: 0.4886
# Epoch 6/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6615 - accuracy: 0.6118 - val_loss: 0.6325 - val_accuracy: 0.5078
# Epoch 7/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6627 - accuracy: 0.5891 - val_loss: 0.6608 - val_accuracy: 0.5245
# Epoch 8/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6615 - accuracy: 0.5864 - val_loss: 0.7125 - val_accuracy: 0.4594
# Epoch 9/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6573 - accuracy: 0.5994 - val_loss: 0.7237 - val_accuracy: 0.3799
# Epoch 10/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6614 - accuracy: 0.5766 - val_loss: 0.6915 - val_accuracy: 0.5048
# Epoch 11/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6588 - accuracy: 0.6082 - val_loss: 0.7816 - val_accuracy: 0.4211
# Epoch 12/100
# 184/184 [==============================] - 7s 37ms/step - loss: 0.6630 - accuracy: 0.5925 - val_loss: 0.7667 - val_accuracy: 0.4516
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6869 - accuracy: 0.5520
# Training took a total of 191 seconds
# Training by looking back 48 hours of important STATE NAME data
# Epoch 1/100
# 183/183 [==============================] - 16s 74ms/step - loss: 0.6807 - accuracy: 0.5789 - val_loss: 0.6709 - val_accuracy: 0.4318
# Epoch 2/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6852 - accuracy: 0.5938 - val_loss: 0.7737 - val_accuracy: 0.3929
# Epoch 3/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6760 - accuracy: 0.5620 - val_loss: 0.7209 - val_accuracy: 0.4252
# Epoch 4/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6693 - accuracy: 0.6032 - val_loss: 0.7198 - val_accuracy: 0.4264
# Epoch 5/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6772 - accuracy: 0.5697 - val_loss: 0.8186 - val_accuracy: 0.2727
# Epoch 6/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6718 - accuracy: 0.5675 - val_loss: 0.6510 - val_accuracy: 0.4707
# Epoch 7/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6725 - accuracy: 0.5795 - val_loss: 0.6780 - val_accuracy: 0.4330
# Epoch 8/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6705 - accuracy: 0.5952 - val_loss: 0.7011 - val_accuracy: 0.4300
# Epoch 9/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6862 - accuracy: 0.5730 - val_loss: 0.6952 - val_accuracy: 0.2297
# Epoch 10/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6809 - accuracy: 0.5357 - val_loss: 0.6966 - val_accuracy: 0.3642
# Epoch 11/100
# 183/183 [==============================] - 13s 71ms/step - loss: 0.6746 - accuracy: 0.5557 - val_loss: 0.8071 - val_accuracy: 0.2990
# 27/27 [==============================] - 0s 17ms/step - loss: 0.7383 - accuracy: 0.4170
# Training took a total of 257 seconds
# Training by looking back 72 hours of important STATE NAME data
# Epoch 1/100
# 183/183 [==============================] - 23s 111ms/step - loss: 0.6856 - accuracy: 0.5933 - val_loss: 0.7814 - val_accuracy: 0.3419
# Epoch 2/100
# 183/183 [==============================] - 20s 107ms/step - loss: 0.6819 - accuracy: 0.5490 - val_loss: 0.7339 - val_accuracy: 0.4246
# Epoch 3/100
# 183/183 [==============================] - 20s 107ms/step - loss: 0.6818 - accuracy: 0.5926 - val_loss: 0.7013 - val_accuracy: 0.4204
# Epoch 4/100
# 183/183 [==============================] - 20s 107ms/step - loss: 0.6781 - accuracy: 0.6155 - val_loss: 0.7990 - val_accuracy: 0.4012
# Epoch 5/100
# 183/183 [==============================] - 20s 111ms/step - loss: 0.6789 - accuracy: 0.5757 - val_loss: 0.7402 - val_accuracy: 0.4222
# Epoch 6/100
# 183/183 [==============================] - 20s 108ms/step - loss: 0.6768 - accuracy: 0.6082 - val_loss: 0.7955 - val_accuracy: 0.3898
# Epoch 7/100
# 183/183 [==============================] - 20s 111ms/step - loss: 0.6788 - accuracy: 0.5911 - val_loss: 0.7578 - val_accuracy: 0.3641
# 27/27 [==============================] - 1s 30ms/step - loss: 0.6987 - accuracy: 0.5455
# Training took a total of 253 seconds
# Training by looking back 96 hours of important STATE NAME data
# Epoch 1/100
# 183/183 [==============================] - 29s 145ms/step - loss: 0.6942 - accuracy: 0.5405 - val_loss: 0.6265 - val_accuracy: 0.8406
# Epoch 2/100
# 183/183 [==============================] - 26s 141ms/step - loss: 0.6867 - accuracy: 0.5602 - val_loss: 0.7821 - val_accuracy: 0.3649
# Epoch 3/100
# 183/183 [==============================] - 26s 142ms/step - loss: 0.6895 - accuracy: 0.5961 - val_loss: 0.7141 - val_accuracy: 0.4386
# Epoch 4/100
# 183/183 [==============================] - 26s 142ms/step - loss: 0.6836 - accuracy: 0.5972 - val_loss: 0.6407 - val_accuracy: 0.7669
# Epoch 5/100
# 183/183 [==============================] - 28s 152ms/step - loss: 0.6902 - accuracy: 0.5288 - val_loss: 0.7047 - val_accuracy: 0.4272
# Epoch 6/100
# 183/183 [==============================] - 30s 162ms/step - loss: 0.6797 - accuracy: 0.6085 - val_loss: 0.7907 - val_accuracy: 0.2331
# 27/27 [==============================] - 1s 41ms/step - loss: 0.7332 - accuracy: 0.3353
# Training took a total of 278 seconds

# %%
seq_result
# Out:
# {(12, 6): [0.6557784676551819, 0.6348448395729065],
#  (24, 12): [0.6868782043457031, 0.5519713163375854],
#  (48, 24): [0.7382815480232239, 0.4169653654098511],
#  (72, 37): [0.6986674070358276, 0.5454545617103577],
#  (96, 49): [0.7332104444503784, 0.3353293538093567]}

# %% [markdown]
# # Training with Embedding Layer, multiple inputs
#
# ### one categorical variable + one numerical variable
# #### model overfits very badly, introduce some callbacks and Dropout
# #### TODO: check if the target value is computed correctly, values looks suspicious

# %%
def label_encode(statename_seq): # do this the manual way as we are not certain if sklearn LabelEncoder can handle 3D array
    all_unique_statename = [set(ele) for ele in statename_seq]
    unique_statenames = set()
    for ele in all_unique_statename:
        unique_statenames |= ele
    
    enc_label = 1  #start encoding from 1 as we have to pad the sequence with 0
    mapping_dict = {}
    for ele in unique_statenames:
        mapping_dict[ele] = enc_label
        enc_label += 1

        enc_array = []
        
    #X_seq is a 3D array
    for timestamp in statename_seq:
        tmp_arr = []
        for ele in timestamp:
            tmp_arr.append(mapping_dict[ele])
        enc_array.append(np.array(tmp_arr))

    return np.array(enc_array), len(unique_statenames)+1

# %%
def remove_empty_datapoint(impt_state_seq, impt_duration_seq, major_down_arr):
    print(f"Remove {len([ele for ele in impt_state_seq if len(ele)==0])} rows on WBA124 out of {len(impt_state_seq)} as it has no data")
    bool_arr = [len(ele)==0 for ele in impt_state_seq] #this is to find the index to remove for bot y array and X_seq
    idx_remove = np.where(bool_arr)[0]
    
    major_down_arr = np.delete(np.array(major_down_arr), idx_remove) # remove the corresponding y value as well
    impt_state_seq = np.delete(impt_state_seq, idx_remove) #remove rows with no state name
    impt_duration_seq = np.delete(impt_duration_seq, idx_remove)
    return impt_state_seq, impt_duration_seq, major_down_arr

# %%
def randomly_select_negative(X_seq, X_dur, major_down_arr, ratio):
    bool_arr = [ele==0 for ele in major_down_arr]
    major_arr = np.array(major_down_arr)[np.where(bool_arr)[0]]
    print(len(major_arr), len(major_down_arr))
    negative = X_seq[np.where(bool_arr)[0]]
    duration = X_dur[np.where(bool_arr)[0]]
    
    positive_bool_arr = [ele==1 for ele in major_down_arr]
    positive_major_arr = np.array(major_down_arr)[np.where(positive_bool_arr)[0]]
    print(len(positive_major_arr))
    positive = X_seq[np.where(positive_bool_arr)[0]]
    positive_dur = X_dur[np.where(positive_bool_arr)[0]]
    
    discard, keep, dur_discard, dur_keep, target_discard, target_keep = train_test_split(negative, duration, major_arr, test_size=ratio)
    
    handpicked = np.concatenate((positive, keep))
    dur = np.concatenate((positive_dur, dur_keep))
    target = np.concatenate((positive_major_arr, target_keep))
    
    if len(handpicked) != len(dur) or len(handpicked) != len(target):
        raise Exception("Length of training inputs are different")
    
    return handpicked, dur, target

# %%
seq_result = {}
lookback = [12, 24, 48, 72]
count = 0
mode = "max"
for hour in lookback:
    if count  == 0:
        monitor = "val_recall"
    else:
        monitor = f"val_recall_{count}"
    
    count += 1
    #NEW MACHINES WITH LITTLE DATA: 120, 121 122, 125
    #CAN USE 123, 124, 126, 127, 128, 129, 130, 131, 132, 133
    wba123 = status_LSTM("WBA123", hour, 3)
    wba124 = status_LSTM("WBA124", hour, 3)
    wba126 = status_LSTM("WBA126", hour, 3)
    wba127 = status_LSTM("WBA127", hour, 3)
    wba128 = status_LSTM("WBA128", hour, 3)
    
    #remove data points
    wba123.impt_state_seq, wba123.impt_duration_seq, wba123.major_down_arr = remove_empty_datapoint(wba123.impt_state_seq, wba123.impt_duration_seq, wba123.major_down_arr)
    wba124.impt_state_seq, wba124.impt_duration_seq, wba124.major_down_arr = remove_empty_datapoint(wba124.impt_state_seq, wba124.impt_duration_seq, wba124.major_down_arr)
    wba126.impt_state_seq, wba126.impt_duration_seq, wba126.major_down_arr = remove_empty_datapoint(wba126.impt_state_seq, wba126.impt_duration_seq, wba126.major_down_arr)
    wba127.impt_state_seq, wba127.impt_duration_seq, wba127.major_down_arr = remove_empty_datapoint(wba127.impt_state_seq, wba127.impt_duration_seq, wba127.major_down_arr)
    wba128.impt_state_seq, wba128.impt_duration_seq, wba128.major_down_arr = remove_empty_datapoint(wba128.impt_state_seq, wba128.impt_duration_seq, wba128.major_down_arr)

    start = datetime.now()
    tmp1 = np.concatenate((wba123.impt_state_seq, wba124.impt_state_seq, wba126.impt_state_seq, wba127.impt_state_seq, wba128.impt_state_seq))
    encoded_X_seq, n_statename = label_encode(tmp1)
    numerical_X_seq = np.concatenate((wba123.impt_duration_seq, wba124.impt_duration_seq, wba126.impt_duration_seq, wba127.impt_duration_seq, wba128.impt_duration_seq,)) # one numerical variable (duration associated with the statename)
    target = np.concatenate((wba123.major_down_arr, wba124.major_down_arr, wba126.major_down_arr, wba127.major_down_arr, wba128.major_down_arr, ))
    
    # downsample negative data
    encoded_X_seq, numerical_X_seq, target = randomly_select_negative(encoded_X_seq, numerical_X_seq,  target, 0.2)
    
    #shuffle the X and Y values to make generalize better
    shuffled = shuffle(encoded_X_seq, numerical_X_seq, target)
    encoded_X_seq = shuffled[0]
    numerical_X_seq = shuffled[1]
    target = shuffled[2]
    
    # padding to average length
    mean_length = int(np.mean([len(x) for x in encoded_X_seq]))
    padded_statename = np.zeros([len(encoded_X_seq), mean_length])
    padded_duration = np.zeros([len(encoded_X_seq), mean_length])
    for i,j in enumerate(encoded_X_seq):
        padded_statename[i][0:len(j)] = j[:mean_length]
        padded_duration[i][0:len(j)] = numerical_X_seq[i][:mean_length]

    #train_val_test split
    X_train_statename_seq, X_val_statename_seq, X_train_duration_seq, X_val_duration_seq, y_train_seq, y_val_seq =  train_test_split(padded_statename, padded_duration, target, test_size=0.4, random_state=42, stratify=target)
    X_val_statename_seq, X_test_statename_seq, X_val_duration_seq, X_test_duration_seq, y_val_seq, y_test_seq =  train_test_split(X_val_statename_seq, X_val_duration_seq, y_val_seq, test_size=0.4, random_state=42, stratify=y_val_seq)    
    
    # embed the categorical variable using Keras Functional API
    in_layer = Input(shape=(X_train_statename_seq.shape[1],), name="statename")
    em_layer = Embedding(n_statename, 128, mask_zero=True)(in_layer)
    em_layer = Reshape((X_train_statename_seq.shape[1], -1))(em_layer)

    # input layer for numerical variable
    in_num = Input(shape=(X_train_duration_seq.shape[1], 1), name="duration")

    merge = concatenate([em_layer, in_num])
    lstm_layer1 = Bidirectional(LSTM(128, return_sequences=True))(merge)
    dropout1 = Dropout(0.5)(lstm_layer1)
    lstm_layer2 = LSTM(64)(dropout1)
    dropout2 = Dropout(0.5)(lstm_layer2)
    dense = Dense(64, activation='relu')(dropout2)
    classifier = Dense(1, activation='sigmoid')(dense)

    all_inputs = [in_layer, in_num]
    model = Model(inputs=all_inputs, outputs=classifier)

    # model seems to be overfitting, try to reduce overfitting by reduce LR, but model should take longer to converge so use a larger EPOCH
    callbacks = [ReduceLROnPlateau(monitor=monitor, factor=0.2, patience=5, min_lr=0.001), \
                EarlyStopping(monitor=monitor, mode=mode, patience=30, restore_best_weights=True)]

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'accuracy'])

    model.fit([X_train_statename_seq, X_train_duration_seq], y_train_seq,
             validation_data=([X_val_statename_seq, X_val_duration_seq], y_val_seq),
             callbacks=callbacks, epochs=EPOCHS, batch_size=BATCH_SIZE)

    evaluate = model.evaluate([X_test_statename_seq, X_test_duration_seq], y_test_seq) #loss, mse
    
    pred = model.predict([X_test_statename_seq, X_test_duration_seq])
    classes = []
    for ele in pred:
        classes.append(int((ele>0.5)[0]))

    from sklearn.metrics import classification_report, confusion_matrix

    cm = confusion_matrix(y_test_seq, classes)
    print(cm)
    
    seq_result[hour] = [evaluate, cm]

    end = datetime.now()
    time = end - start
    print(f"Training took {time.seconds} seconds to complete.")
# Out:
# Remove 2835 rows on WBA124 out of 8357 as it has no data
# Remove 2971 rows on WBA124 out of 8381 as it has no data
# Remove 2314 rows on WBA124 out of 8381 as it has no data
# Remove 2760 rows on WBA124 out of 8381 as it has no data
# Remove 2526 rows on WBA124 out of 8341 as it has no data
# 24669 28435
# 3766
# Epoch 1/300
# 164/164 [==============================] - 11s 32ms/step - loss: 0.6794 - precision: 0.5102 - recall: 0.2996 - accuracy: 0.5722 - val_loss: 0.6777 - val_precision: 0.4975 - val_recall: 0.2190 - val_accuracy: 0.5661
# Epoch 2/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6762 - precision: 0.5288 - recall: 0.3288 - accuracy: 0.5826 - val_loss: 0.6743 - val_precision: 0.5114 - val_recall: 0.3960 - val_accuracy: 0.5747
# Epoch 3/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6777 - precision: 0.5109 - recall: 0.2491 - accuracy: 0.5716 - val_loss: 0.6735 - val_precision: 0.3333 - val_recall: 0.0100 - val_accuracy: 0.5627
# Epoch 4/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6755 - precision: 0.5171 - recall: 0.3013 - accuracy: 0.5757 - val_loss: 0.6734 - val_precision: 0.5104 - val_recall: 0.4060 - val_accuracy: 0.5742
# Epoch 5/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6722 - precision: 0.5217 - recall: 0.3239 - accuracy: 0.5787 - val_loss: 0.6744 - val_precision: 0.5119 - val_recall: 0.4049 - val_accuracy: 0.5752
# Epoch 6/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6740 - precision: 0.5213 - recall: 0.2712 - accuracy: 0.5766 - val_loss: 0.6744 - val_precision: 0.5095 - val_recall: 0.3861 - val_accuracy: 0.5733
# Epoch 7/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6713 - precision: 0.5212 - recall: 0.2934 - accuracy: 0.5774 - val_loss: 0.6834 - val_precision: 0.4000 - val_recall: 0.0022 - val_accuracy: 0.5666
# Epoch 8/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6725 - precision: 0.5269 - recall: 0.2558 - accuracy: 0.5784 - val_loss: 0.6732 - val_precision: 0.5128 - val_recall: 0.3993 - val_accuracy: 0.5757
# Epoch 9/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6715 - precision: 0.5232 - recall: 0.2996 - accuracy: 0.5785 - val_loss: 0.6751 - val_precision: 0.5134 - val_recall: 0.4458 - val_accuracy: 0.5771
# Epoch 10/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6689 - precision: 0.5326 - recall: 0.2642 - accuracy: 0.5810 - val_loss: 0.6758 - val_precision: 0.5123 - val_recall: 0.4591 - val_accuracy: 0.5766
# Epoch 11/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6713 - precision: 0.5225 - recall: 0.3438 - accuracy: 0.5799 - val_loss: 0.6741 - val_precision: 0.5138 - val_recall: 0.4336 - val_accuracy: 0.5771
# Epoch 12/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6710 - precision: 0.5215 - recall: 0.3221 - accuracy: 0.5785 - val_loss: 0.6699 - val_precision: 0.5126 - val_recall: 0.3385 - val_accuracy: 0.5742
# Epoch 13/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6692 - precision: 0.5261 - recall: 0.3296 - accuracy: 0.5812 - val_loss: 0.6698 - val_precision: 0.5119 - val_recall: 0.4524 - val_accuracy: 0.5761
# Epoch 14/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6689 - precision: 0.5313 - recall: 0.3907 - accuracy: 0.5870 - val_loss: 0.6700 - val_precision: 0.5146 - val_recall: 0.4491 - val_accuracy: 0.5781
# Epoch 15/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6690 - precision: 0.5319 - recall: 0.3429 - accuracy: 0.5849 - val_loss: 0.6714 - val_precision: 0.5207 - val_recall: 0.2367 - val_accuracy: 0.5752
# Epoch 16/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6659 - precision: 0.5307 - recall: 0.3137 - accuracy: 0.5828 - val_loss: 0.6739 - val_precision: 0.5157 - val_recall: 0.4546 - val_accuracy: 0.5790
# Epoch 17/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6671 - precision: 0.5315 - recall: 0.3664 - accuracy: 0.5858 - val_loss: 0.6707 - val_precision: 0.5172 - val_recall: 0.4314 - val_accuracy: 0.5795
# Epoch 18/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6642 - precision: 0.5350 - recall: 0.3788 - accuracy: 0.5885 - val_loss: 0.6709 - val_precision: 0.5220 - val_recall: 0.1969 - val_accuracy: 0.5742
# Epoch 19/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6662 - precision: 0.5258 - recall: 0.3332 - accuracy: 0.5812 - val_loss: 0.6742 - val_precision: 0.5022 - val_recall: 0.5055 - val_accuracy: 0.5690
# Epoch 20/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6637 - precision: 0.5269 - recall: 0.3898 - accuracy: 0.5843 - val_loss: 0.6708 - val_precision: 0.5155 - val_recall: 0.4613 - val_accuracy: 0.5790
# Epoch 21/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6637 - precision: 0.5411 - recall: 0.3814 - accuracy: 0.5921 - val_loss: 0.6709 - val_precision: 0.5170 - val_recall: 0.4878 - val_accuracy: 0.5809
# Epoch 22/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6634 - precision: 0.5463 - recall: 0.3841 - accuracy: 0.5952 - val_loss: 0.6710 - val_precision: 0.5212 - val_recall: 0.4491 - val_accuracy: 0.5829
# Epoch 23/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6608 - precision: 0.5439 - recall: 0.3752 - accuracy: 0.5933 - val_loss: 0.6736 - val_precision: 0.5182 - val_recall: 0.4414 - val_accuracy: 0.5805
# Epoch 24/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6623 - precision: 0.5437 - recall: 0.3549 - accuracy: 0.5918 - val_loss: 0.6711 - val_precision: 0.5197 - val_recall: 0.4369 - val_accuracy: 0.5814
# Epoch 25/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6614 - precision: 0.5400 - recall: 0.3615 - accuracy: 0.5902 - val_loss: 0.6687 - val_precision: 0.5202 - val_recall: 0.4126 - val_accuracy: 0.5809
# Epoch 26/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6599 - precision: 0.5532 - recall: 0.3748 - accuracy: 0.5983 - val_loss: 0.6727 - val_precision: 0.5137 - val_recall: 0.4558 - val_accuracy: 0.5776
# Epoch 27/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6574 - precision: 0.5465 - recall: 0.3664 - accuracy: 0.5941 - val_loss: 0.6700 - val_precision: 0.5100 - val_recall: 0.2268 - val_accuracy: 0.5709
# Epoch 28/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6562 - precision: 0.5562 - recall: 0.3549 - accuracy: 0.5981 - val_loss: 0.6730 - val_precision: 0.5157 - val_recall: 0.4358 - val_accuracy: 0.5785
# Epoch 29/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6588 - precision: 0.5523 - recall: 0.3832 - accuracy: 0.5985 - val_loss: 0.6716 - val_precision: 0.5211 - val_recall: 0.4381 - val_accuracy: 0.5824
# Epoch 30/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6557 - precision: 0.5526 - recall: 0.4000 - accuracy: 0.6000 - val_loss: 0.6717 - val_precision: 0.5147 - val_recall: 0.2909 - val_accuracy: 0.5742
# Epoch 31/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6523 - precision: 0.5608 - recall: 0.3633 - accuracy: 0.6011 - val_loss: 0.6888 - val_precision: 0.5176 - val_recall: 0.4723 - val_accuracy: 0.5809
# Epoch 32/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6516 - precision: 0.5603 - recall: 0.3801 - accuracy: 0.6025 - val_loss: 0.6758 - val_precision: 0.5158 - val_recall: 0.3606 - val_accuracy: 0.5766
# Epoch 33/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6490 - precision: 0.5598 - recall: 0.3708 - accuracy: 0.6013 - val_loss: 0.6750 - val_precision: 0.5195 - val_recall: 0.4558 - val_accuracy: 0.5819
# Epoch 34/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6526 - precision: 0.5540 - recall: 0.4221 - accuracy: 0.6027 - val_loss: 0.6823 - val_precision: 0.5119 - val_recall: 0.4038 - val_accuracy: 0.5752
# Epoch 35/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6538 - precision: 0.5622 - recall: 0.3717 - accuracy: 0.6027 - val_loss: 0.6737 - val_precision: 0.5249 - val_recall: 0.4204 - val_accuracy: 0.5843
# Epoch 36/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6448 - precision: 0.5690 - recall: 0.4217 - accuracy: 0.6113 - val_loss: 0.6944 - val_precision: 0.5221 - val_recall: 0.4834 - val_accuracy: 0.5848
# Epoch 37/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6455 - precision: 0.5619 - recall: 0.4195 - accuracy: 0.6071 - val_loss: 0.6815 - val_precision: 0.5230 - val_recall: 0.3905 - val_accuracy: 0.5819
# Epoch 38/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6447 - precision: 0.5646 - recall: 0.4119 - accuracy: 0.6079 - val_loss: 0.6866 - val_precision: 0.5292 - val_recall: 0.4812 - val_accuracy: 0.5900
# Epoch 39/300
# 164/164 [==============================] - 4s 24ms/step - loss: 0.6474 - precision: 0.5581 - recall: 0.4274 - accuracy: 0.6056 - val_loss: 0.6777 - val_precision: 0.5230 - val_recall: 0.3650 - val_accuracy: 0.5809
# Epoch 40/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6440 - precision: 0.5735 - recall: 0.3575 - accuracy: 0.6067 - val_loss: 0.6868 - val_precision: 0.5280 - val_recall: 0.4491 - val_accuracy: 0.5876
# Epoch 41/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6409 - precision: 0.5660 - recall: 0.4190 - accuracy: 0.6094 - val_loss: 0.6894 - val_precision: 0.5252 - val_recall: 0.4148 - val_accuracy: 0.5843
# Epoch 42/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6392 - precision: 0.5696 - recall: 0.4164 - accuracy: 0.6111 - val_loss: 0.6776 - val_precision: 0.5146 - val_recall: 0.4082 - val_accuracy: 0.5771
# Epoch 43/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6382 - precision: 0.5660 - recall: 0.4403 - accuracy: 0.6115 - val_loss: 0.6860 - val_precision: 0.5232 - val_recall: 0.4115 - val_accuracy: 0.5829
# Epoch 44/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6378 - precision: 0.5658 - recall: 0.4394 - accuracy: 0.6113 - val_loss: 0.6879 - val_precision: 0.5211 - val_recall: 0.4104 - val_accuracy: 0.5814
# Epoch 45/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6381 - precision: 0.5672 - recall: 0.4088 - accuracy: 0.6090 - val_loss: 0.6817 - val_precision: 0.5225 - val_recall: 0.4624 - val_accuracy: 0.5843
# Epoch 46/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6373 - precision: 0.5642 - recall: 0.4296 - accuracy: 0.6094 - val_loss: 0.6897 - val_precision: 0.5193 - val_recall: 0.4624 - val_accuracy: 0.5819
# Epoch 47/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6318 - precision: 0.5738 - recall: 0.4336 - accuracy: 0.6153 - val_loss: 0.6903 - val_precision: 0.5216 - val_recall: 0.4281 - val_accuracy: 0.5824
# Epoch 48/300
# 164/164 [==============================] - 4s 23ms/step - loss: 0.6334 - precision: 0.5834 - recall: 0.4164 - accuracy: 0.6186 - val_loss: 0.6951 - val_precision: 0.5184 - val_recall: 0.3894 - val_accuracy: 0.5790
# Epoch 49/300
# 164/164 [==============================] - 4s 25ms/step - loss: 0.6323 - precision: 0.5788 - recall: 0.3819 - accuracy: 0.6121 - val_loss: 0.7035 - val_precision: 0.5247 - val_recall: 0.4226 - val_accuracy: 0.5843
# 44/44 [==============================] - 0s 6ms/step - loss: 0.6720 - precision: 0.4983 - recall: 0.4734 - accuracy: 0.5661
# [[503 287]
#  [317 285]]
# Training took 201 seconds to complete.
# Remove 1931 rows on WBA124 out of 8353 as it has no data
# Remove 1865 rows on WBA124 out of 8377 as it has no data
# Remove 1570 rows on WBA124 out of 8377 as it has no data
# Remove 1707 rows on WBA124 out of 8377 as it has no data
# Remove 1547 rows on WBA124 out of 8337 as it has no data
# 29092 33201
# 4109
# Epoch 1/300
# 187/187 [==============================] - 13s 45ms/step - loss: 0.6809 - precision_1: 0.4725 - recall_1: 0.1951 - accuracy: 0.5767 - val_loss: 0.6723 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_accuracy: 0.5862
# Epoch 2/300
# 187/187 [==============================] - 7s 36ms/step - loss: 0.6740 - precision_1: 0.4642 - recall_1: 0.1550 - accuracy: 0.5762 - val_loss: 0.6737 - val_precision_1: 0.4893 - val_recall_1: 0.3955 - val_accuracy: 0.5791
# Epoch 3/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6730 - precision_1: 0.4913 - recall_1: 0.1489 - accuracy: 0.5839 - val_loss: 0.6727 - val_precision_1: 0.4901 - val_recall_1: 0.3529 - val_accuracy: 0.5804
# Epoch 4/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6731 - precision_1: 0.5166 - recall_1: 0.1639 - accuracy: 0.5905 - val_loss: 0.6735 - val_precision_1: 0.4880 - val_recall_1: 0.3509 - val_accuracy: 0.5791
# Epoch 5/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6730 - precision_1: 0.4904 - recall_1: 0.1452 - accuracy: 0.5838 - val_loss: 0.6720 - val_precision_1: 0.5027 - val_recall_1: 0.2819 - val_accuracy: 0.5875
# Epoch 6/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6723 - precision_1: 0.5065 - recall_1: 0.1420 - accuracy: 0.5876 - val_loss: 0.6717 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_accuracy: 0.5862
# Epoch 7/300
# 187/187 [==============================] - 7s 36ms/step - loss: 0.6719 - precision_1: 0.4862 - recall_1: 0.0929 - accuracy: 0.5839 - val_loss: 0.6776 - val_precision_1: 0.5000 - val_recall_1: 0.2556 - val_accuracy: 0.5862
# Epoch 8/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6735 - precision_1: 0.4643 - recall_1: 0.1266 - accuracy: 0.5781 - val_loss: 0.6719 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_accuracy: 0.5862
# Epoch 9/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6707 - precision_1: 0.4770 - recall_1: 0.0799 - accuracy: 0.5829 - val_loss: 0.6741 - val_precision_1: 0.4920 - val_recall_1: 0.4047 - val_accuracy: 0.5808
# Epoch 10/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6723 - precision_1: 0.4636 - recall_1: 0.1318 - accuracy: 0.5776 - val_loss: 0.6721 - val_precision_1: 0.5045 - val_recall_1: 0.2860 - val_accuracy: 0.5883
# Epoch 11/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6709 - precision_1: 0.4985 - recall_1: 0.1391 - accuracy: 0.5858 - val_loss: 0.6717 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_accuracy: 0.5862
# Epoch 12/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6715 - precision_1: 0.5132 - recall_1: 0.0868 - accuracy: 0.5880 - val_loss: 0.6729 - val_precision_1: 0.4892 - val_recall_1: 0.3905 - val_accuracy: 0.5791
# Epoch 13/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6717 - precision_1: 0.5046 - recall_1: 0.1112 - accuracy: 0.5870 - val_loss: 0.6722 - val_precision_1: 0.5129 - val_recall_1: 0.2627 - val_accuracy: 0.5917
# Epoch 14/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6702 - precision_1: 0.4972 - recall_1: 0.1428 - accuracy: 0.5855 - val_loss: 0.6727 - val_precision_1: 0.5101 - val_recall_1: 0.2809 - val_accuracy: 0.5909
# Epoch 15/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6709 - precision_1: 0.5046 - recall_1: 0.1108 - accuracy: 0.5870 - val_loss: 0.6721 - val_precision_1: 0.4864 - val_recall_1: 0.3448 - val_accuracy: 0.5783
# Epoch 16/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6698 - precision_1: 0.4971 - recall_1: 0.1716 - accuracy: 0.5853 - val_loss: 0.6724 - val_precision_1: 1.0000 - val_recall_1: 0.0020 - val_accuracy: 0.5871
# Epoch 17/300
# 187/187 [==============================] - 7s 36ms/step - loss: 0.6716 - precision_1: 0.5014 - recall_1: 0.1485 - accuracy: 0.5865 - val_loss: 0.6711 - val_precision_1: 0.5038 - val_recall_1: 0.2718 - val_accuracy: 0.5879
# Epoch 18/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6696 - precision_1: 0.4938 - recall_1: 0.0807 - accuracy: 0.5853 - val_loss: 0.6713 - val_precision_1: 0.5348 - val_recall_1: 0.1714 - val_accuracy: 0.5955
# Epoch 19/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6703 - precision_1: 0.4955 - recall_1: 0.1347 - accuracy: 0.5851 - val_loss: 0.6736 - val_precision_1: 0.4875 - val_recall_1: 0.3742 - val_accuracy: 0.5783
# Epoch 20/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6704 - precision_1: 0.5017 - recall_1: 0.1757 - accuracy: 0.5866 - val_loss: 0.6722 - val_precision_1: 1.0000 - val_recall_1: 0.0020 - val_accuracy: 0.5871
# Epoch 21/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6690 - precision_1: 0.5024 - recall_1: 0.0852 - accuracy: 0.5865 - val_loss: 0.6703 - val_precision_1: 0.6176 - val_recall_1: 0.0213 - val_accuracy: 0.5896
# Epoch 22/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6699 - precision_1: 0.5063 - recall_1: 0.1314 - accuracy: 0.5875 - val_loss: 0.6751 - val_precision_1: 0.5179 - val_recall_1: 0.0294 - val_accuracy: 0.5871
# Epoch 23/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6696 - precision_1: 0.4979 - recall_1: 0.0982 - accuracy: 0.5858 - val_loss: 0.6707 - val_precision_1: 0.4841 - val_recall_1: 0.1856 - val_accuracy: 0.5812
# Epoch 24/300
# 187/187 [==============================] - 7s 36ms/step - loss: 0.6682 - precision_1: 0.5161 - recall_1: 0.1623 - accuracy: 0.5903 - val_loss: 0.6705 - val_precision_1: 0.5274 - val_recall_1: 0.2343 - val_accuracy: 0.5963
# Epoch 25/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6699 - precision_1: 0.4935 - recall_1: 0.1546 - accuracy: 0.5845 - val_loss: 0.6704 - val_precision_1: 0.5226 - val_recall_1: 0.2698 - val_accuracy: 0.5959
# Epoch 26/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6679 - precision_1: 0.5069 - recall_1: 0.1339 - accuracy: 0.5876 - val_loss: 0.6710 - val_precision_1: 0.8462 - val_recall_1: 0.0112 - val_accuracy: 0.5900
# Epoch 27/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6662 - precision_1: 0.5027 - recall_1: 0.1116 - accuracy: 0.5866 - val_loss: 0.6704 - val_precision_1: 0.8182 - val_recall_1: 0.0091 - val_accuracy: 0.5892
# Epoch 28/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6672 - precision_1: 0.5066 - recall_1: 0.1558 - accuracy: 0.5878 - val_loss: 0.6703 - val_precision_1: 0.7778 - val_recall_1: 0.0142 - val_accuracy: 0.5904
# Epoch 29/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6676 - precision_1: 0.4697 - recall_1: 0.0722 - accuracy: 0.5823 - val_loss: 0.6699 - val_precision_1: 0.5165 - val_recall_1: 0.0477 - val_accuracy: 0.5875
# Epoch 30/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6656 - precision_1: 0.4995 - recall_1: 0.2219 - accuracy: 0.5860 - val_loss: 0.6692 - val_precision_1: 0.7273 - val_recall_1: 0.0081 - val_accuracy: 0.5883
# Epoch 31/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6664 - precision_1: 0.4771 - recall_1: 0.0677 - accuracy: 0.5834 - val_loss: 0.6703 - val_precision_1: 0.7500 - val_recall_1: 0.0061 - val_accuracy: 0.5879
# Epoch 32/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6654 - precision_1: 0.5140 - recall_1: 0.1939 - accuracy: 0.5905 - val_loss: 0.6686 - val_precision_1: 0.5897 - val_recall_1: 0.0233 - val_accuracy: 0.5892
# Epoch 33/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6639 - precision_1: 0.5200 - recall_1: 0.1793 - accuracy: 0.5918 - val_loss: 0.6695 - val_precision_1: 0.6087 - val_recall_1: 0.0284 - val_accuracy: 0.5904
# Epoch 34/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6650 - precision_1: 0.5128 - recall_1: 0.1546 - accuracy: 0.5893 - val_loss: 0.6698 - val_precision_1: 0.5317 - val_recall_1: 0.1105 - val_accuracy: 0.5917
# Epoch 35/300
# 187/187 [==============================] - 7s 39ms/step - loss: 0.6623 - precision_1: 0.5412 - recall_1: 0.2479 - accuracy: 0.6017 - val_loss: 0.6672 - val_precision_1: 0.6481 - val_recall_1: 0.0710 - val_accuracy: 0.5997
# Epoch 36/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6612 - precision_1: 0.5373 - recall_1: 0.2426 - accuracy: 0.6001 - val_loss: 0.6686 - val_precision_1: 0.5290 - val_recall_1: 0.2870 - val_accuracy: 0.5992
# Epoch 37/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6635 - precision_1: 0.5229 - recall_1: 0.1947 - accuracy: 0.5932 - val_loss: 0.6693 - val_precision_1: 0.5938 - val_recall_1: 0.0193 - val_accuracy: 0.5888
# Epoch 38/300
# 187/187 [==============================] - 7s 38ms/step - loss: 0.6627 - precision_1: 0.5146 - recall_1: 0.1996 - accuracy: 0.5908 - val_loss: 0.6695 - val_precision_1: 0.7083 - val_recall_1: 0.0345 - val_accuracy: 0.5946
# Epoch 39/300
# 187/187 [==============================] - 7s 37ms/step - loss: 0.6622 - precision_1: 0.5427 - recall_1: 0.2012 - accuracy: 0.5992 - val_loss: 0.6676 - val_precision_1: 0.6299 - val_recall_1: 0.0811 - val_accuracy: 0.6001
# 50/50 [==============================] - 0s 10ms/step - loss: 0.6715 - precision_1: 0.4916 - recall_1: 0.4012 - accuracy: 0.5802
# [[658 273]
#  [394 264]]
# Training took 283 seconds to complete.
# Remove 1229 rows on WBA124 out of 8345 as it has no data
# Remove 1070 rows on WBA124 out of 8369 as it has no data
# Remove 1105 rows on WBA124 out of 8369 as it has no data
# Remove 996 rows on WBA124 out of 8369 as it has no data
# Remove 910 rows on WBA124 out of 8329 as it has no data
# 32175 36471
# 4296
# Epoch 1/300
# 202/202 [==============================] - 19s 70ms/step - loss: 0.6730 - precision_2: 0.4694 - recall_2: 0.1517 - accuracy: 0.5918 - val_loss: 0.6710 - val_precision_2: 0.4557 - val_recall_2: 0.4045 - val_accuracy: 0.5682
# Epoch 2/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6682 - precision_2: 0.4861 - recall_2: 0.1354 - accuracy: 0.5966 - val_loss: 0.6691 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 3/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6674 - precision_2: 0.4975 - recall_2: 0.1160 - accuracy: 0.5993 - val_loss: 0.6704 - val_precision_2: 0.4572 - val_recall_2: 0.3628 - val_accuracy: 0.5724
# Epoch 4/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6687 - precision_2: 0.4741 - recall_2: 0.0958 - accuracy: 0.5955 - val_loss: 0.6722 - val_precision_2: 0.4642 - val_recall_2: 0.2958 - val_accuracy: 0.5814
# Epoch 5/300
# 202/202 [==============================] - 13s 66ms/step - loss: 0.6665 - precision_2: 0.4860 - recall_2: 0.1141 - accuracy: 0.5971 - val_loss: 0.6689 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 6/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6664 - precision_2: 0.4895 - recall_2: 0.0900 - accuracy: 0.5982 - val_loss: 0.6686 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 7/300
# 202/202 [==============================] - 13s 63ms/step - loss: 0.6665 - precision_2: 0.4784 - recall_2: 0.0516 - accuracy: 0.5979 - val_loss: 0.6714 - val_precision_2: 0.4567 - val_recall_2: 0.3889 - val_accuracy: 0.5701
# Epoch 8/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6672 - precision_2: 0.4780 - recall_2: 0.1013 - accuracy: 0.5960 - val_loss: 0.6703 - val_precision_2: 0.4540 - val_recall_2: 0.3686 - val_accuracy: 0.5697
# Epoch 9/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6655 - precision_2: 0.4643 - recall_2: 0.1036 - accuracy: 0.5934 - val_loss: 0.6689 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 10/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6640 - precision_2: 0.4615 - recall_2: 0.0349 - accuracy: 0.5974 - val_loss: 0.6695 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 11/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6662 - precision_2: 0.4700 - recall_2: 0.0182 - accuracy: 0.5988 - val_loss: 0.6697 - val_precision_2: 0.4544 - val_recall_2: 0.2658 - val_accuracy: 0.5783
# Epoch 12/300
# 202/202 [==============================] - 13s 65ms/step - loss: 0.6649 - precision_2: 0.4944 - recall_2: 0.0679 - accuracy: 0.5991 - val_loss: 0.6693 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 13/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6650 - precision_2: 0.4760 - recall_2: 0.0578 - accuracy: 0.5974 - val_loss: 0.6688 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 14/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6651 - precision_2: 0.5037 - recall_2: 0.0532 - accuracy: 0.6000 - val_loss: 0.6687 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 15/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6641 - precision_2: 0.5038 - recall_2: 0.0520 - accuracy: 0.6000 - val_loss: 0.6691 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 16/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6659 - precision_2: 0.4432 - recall_2: 0.0454 - accuracy: 0.5951 - val_loss: 0.6700 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 17/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6651 - precision_2: 0.4808 - recall_2: 0.0582 - accuracy: 0.5979 - val_loss: 0.6697 - val_precision_2: 0.4569 - val_recall_2: 0.2774 - val_accuracy: 0.5786
# Epoch 18/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6637 - precision_2: 0.4613 - recall_2: 0.0718 - accuracy: 0.5949 - val_loss: 0.6699 - val_precision_2: 0.4721 - val_recall_2: 0.1397 - val_accuracy: 0.5930
# Epoch 19/300
# 202/202 [==============================] - 13s 63ms/step - loss: 0.6637 - precision_2: 0.4924 - recall_2: 0.0625 - accuracy: 0.5989 - val_loss: 0.6698 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 20/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6637 - precision_2: 0.4944 - recall_2: 0.1191 - accuracy: 0.5986 - val_loss: 0.6681 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 21/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6655 - precision_2: 0.4903 - recall_2: 0.0788 - accuracy: 0.5985 - val_loss: 0.6690 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 22/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6626 - precision_2: 0.4937 - recall_2: 0.0303 - accuracy: 0.5994 - val_loss: 0.6700 - val_precision_2: 0.4568 - val_recall_2: 0.3996 - val_accuracy: 0.5693
# Epoch 23/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6621 - precision_2: 0.4696 - recall_2: 0.1110 - accuracy: 0.5940 - val_loss: 0.6698 - val_precision_2: 0.5000 - val_recall_2: 0.0019 - val_accuracy: 0.5996
# Epoch 24/300
# 202/202 [==============================] - 13s 65ms/step - loss: 0.6620 - precision_2: 0.5142 - recall_2: 0.0702 - accuracy: 0.6013 - val_loss: 0.6711 - val_precision_2: 0.3500 - val_recall_2: 0.0339 - val_accuracy: 0.5880
# Epoch 25/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6597 - precision_2: 0.5046 - recall_2: 0.0850 - accuracy: 0.6003 - val_loss: 0.6681 - val_precision_2: 0.4668 - val_recall_2: 0.3346 - val_accuracy: 0.5806
# Epoch 26/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6600 - precision_2: 0.4877 - recall_2: 0.1312 - accuracy: 0.5971 - val_loss: 0.6681 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_accuracy: 0.5996
# Epoch 27/300
# 202/202 [==============================] - 13s 66ms/step - loss: 0.6593 - precision_2: 0.5149 - recall_2: 0.1005 - accuracy: 0.6021 - val_loss: 0.6703 - val_precision_2: 0.4211 - val_recall_2: 0.0233 - val_accuracy: 0.5961
# Epoch 28/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6558 - precision_2: 0.5079 - recall_2: 0.2006 - accuracy: 0.6022 - val_loss: 0.6658 - val_precision_2: 0.4694 - val_recall_2: 0.0223 - val_accuracy: 0.5984
# Epoch 29/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6538 - precision_2: 0.4902 - recall_2: 0.1653 - accuracy: 0.5971 - val_loss: 0.6677 - val_precision_2: 0.4632 - val_recall_2: 0.3540 - val_accuracy: 0.5771
# Epoch 30/300
# 202/202 [==============================] - 14s 68ms/step - loss: 0.6559 - precision_2: 0.4918 - recall_2: 0.1851 - accuracy: 0.5972 - val_loss: 0.6680 - val_precision_2: 0.4354 - val_recall_2: 0.1862 - val_accuracy: 0.5775
# Epoch 31/300
# 202/202 [==============================] - 13s 64ms/step - loss: 0.6510 - precision_2: 0.5422 - recall_2: 0.2441 - accuracy: 0.6149 - val_loss: 0.6700 - val_precision_2: 0.4364 - val_recall_2: 0.0466 - val_accuracy: 0.5942
# 54/54 [==============================] - 1s 17ms/step - loss: 0.6705 - precision_2: 0.4724 - recall_2: 0.4230 - accuracy: 0.5797
# [[705 325]
#  [397 291]]
# Training took 413 seconds to complete.
# Remove 868 rows on WBA124 out of 8337 as it has no data
# Remove 698 rows on WBA124 out of 8361 as it has no data
# Remove 855 rows on WBA124 out of 8361 as it has no data
# Remove 686 rows on WBA124 out of 8361 as it has no data
# Remove 578 rows on WBA124 out of 8321 as it has no data
# 33701 38056
# 4355
# Epoch 1/300
# 209/209 [==============================] - 26s 101ms/step - loss: 0.6732 - precision_3: 0.4747 - recall_3: 0.0861 - accuracy: 0.6039 - val_loss: 0.6663 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 2/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6695 - precision_3: 0.4330 - recall_3: 0.0432 - accuracy: 0.6022 - val_loss: 0.6660 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 3/300
# 209/209 [==============================] - 18s 88ms/step - loss: 0.6669 - precision_3: 0.5043 - recall_3: 0.0222 - accuracy: 0.6076 - val_loss: 0.6656 - val_precision_3: 0.4754 - val_recall_3: 0.2038 - val_accuracy: 0.5993
# Epoch 4/300
# 209/209 [==============================] - 19s 91ms/step - loss: 0.6664 - precision_3: 0.4500 - recall_3: 0.0620 - accuracy: 0.6021 - val_loss: 0.6698 - val_precision_3: 0.4500 - val_recall_3: 0.0344 - val_accuracy: 0.6046
# Epoch 5/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6670 - precision_3: 0.4901 - recall_3: 0.0283 - accuracy: 0.6070 - val_loss: 0.6662 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 6/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6656 - precision_3: 0.4032 - recall_3: 0.0096 - accuracy: 0.6057 - val_loss: 0.6658 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 7/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6655 - precision_3: 0.4182 - recall_3: 0.0176 - accuracy: 0.6048 - val_loss: 0.6654 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 8/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6652 - precision_3: 0.4706 - recall_3: 0.0122 - accuracy: 0.6069 - val_loss: 0.6642 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 9/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6648 - precision_3: 0.3871 - recall_3: 0.0046 - accuracy: 0.6064 - val_loss: 0.6668 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 10/300
# 209/209 [==============================] - 18s 88ms/step - loss: 0.6650 - precision_3: 0.5122 - recall_3: 0.0241 - accuracy: 0.6079 - val_loss: 0.6651 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 11/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6644 - precision_3: 0.5122 - recall_3: 0.0080 - accuracy: 0.6076 - val_loss: 0.6652 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6076
# Epoch 12/300
# 209/209 [==============================] - 18s 88ms/step - loss: 0.6654 - precision_3: 0.4937 - recall_3: 0.0149 - accuracy: 0.6073 - val_loss: 0.6676 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6068
# Epoch 13/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6638 - precision_3: 0.5714 - recall_3: 0.0031 - accuracy: 0.6078 - val_loss: 0.6666 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_accuracy: 0.6072
# Epoch 14/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6655 - precision_3: 0.4286 - recall_3: 0.0149 - accuracy: 0.6055 - val_loss: 0.6657 - val_precision_3: 0.2000 - val_recall_3: 9.5694e-04 - val_accuracy: 0.6065
# Epoch 15/300
# 209/209 [==============================] - 19s 92ms/step - loss: 0.6632 - precision_3: 0.4098 - recall_3: 0.0096 - accuracy: 0.6058 - val_loss: 0.6657 - val_precision_3: 0.2500 - val_recall_3: 9.5694e-04 - val_accuracy: 0.6068
# Epoch 16/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6625 - precision_3: 0.5072 - recall_3: 0.0134 - accuracy: 0.6076 - val_loss: 0.6664 - val_precision_3: 0.5556 - val_recall_3: 0.0096 - val_accuracy: 0.6083
# Epoch 17/300
# 209/209 [==============================] - 18s 88ms/step - loss: 0.6631 - precision_3: 0.4604 - recall_3: 0.0356 - accuracy: 0.6051 - val_loss: 0.6647 - val_precision_3: 0.4286 - val_recall_3: 0.0029 - val_accuracy: 0.6072
# Epoch 18/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6631 - precision_3: 0.4286 - recall_3: 0.0218 - accuracy: 0.6046 - val_loss: 0.6648 - val_precision_3: 0.4286 - val_recall_3: 0.0029 - val_accuracy: 0.6072
# Epoch 19/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6641 - precision_3: 0.5096 - recall_3: 0.0203 - accuracy: 0.6078 - val_loss: 0.6652 - val_precision_3: 0.5455 - val_recall_3: 0.0115 - val_accuracy: 0.6083
# Epoch 20/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6626 - precision_3: 0.5537 - recall_3: 0.0256 - accuracy: 0.6094 - val_loss: 0.6656 - val_precision_3: 0.5455 - val_recall_3: 0.0115 - val_accuracy: 0.6083
# Epoch 21/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6631 - precision_3: 0.5274 - recall_3: 0.0406 - accuracy: 0.6091 - val_loss: 0.6656 - val_precision_3: 0.4902 - val_recall_3: 0.0239 - val_accuracy: 0.6072
# Epoch 22/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6616 - precision_3: 0.5000 - recall_3: 0.0593 - accuracy: 0.6075 - val_loss: 0.6647 - val_precision_3: 0.5806 - val_recall_3: 0.0172 - val_accuracy: 0.6095
# Epoch 23/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6629 - precision_3: 0.5342 - recall_3: 0.0628 - accuracy: 0.6106 - val_loss: 0.6647 - val_precision_3: 0.6538 - val_recall_3: 0.0163 - val_accuracy: 0.6106
# Epoch 24/300
# 209/209 [==============================] - 18s 89ms/step - loss: 0.6618 - precision_3: 0.5028 - recall_3: 0.0341 - accuracy: 0.6076 - val_loss: 0.6652 - val_precision_3: 0.5200 - val_recall_3: 0.0249 - val_accuracy: 0.6083
# Epoch 25/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6602 - precision_3: 0.5426 - recall_3: 0.0463 - accuracy: 0.6103 - val_loss: 0.6652 - val_precision_3: 0.6774 - val_recall_3: 0.0201 - val_accuracy: 0.6117
# Epoch 26/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6613 - precision_3: 0.5143 - recall_3: 0.0689 - accuracy: 0.6090 - val_loss: 0.6631 - val_precision_3: 0.6000 - val_recall_3: 0.0115 - val_accuracy: 0.6091
# Epoch 27/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6615 - precision_3: 0.4764 - recall_3: 0.0387 - accuracy: 0.6060 - val_loss: 0.6632 - val_precision_3: 0.6957 - val_recall_3: 0.0153 - val_accuracy: 0.6110
# Epoch 28/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6601 - precision_3: 0.5362 - recall_3: 0.0283 - accuracy: 0.6090 - val_loss: 0.6638 - val_precision_3: 0.6667 - val_recall_3: 0.0191 - val_accuracy: 0.6113
# Epoch 29/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6598 - precision_3: 0.5394 - recall_3: 0.0498 - accuracy: 0.6103 - val_loss: 0.6642 - val_precision_3: 0.6400 - val_recall_3: 0.0306 - val_accuracy: 0.6128
# Epoch 30/300
# 209/209 [==============================] - 19s 91ms/step - loss: 0.6599 - precision_3: 0.5570 - recall_3: 0.0318 - accuracy: 0.6100 - val_loss: 0.6647 - val_precision_3: 0.6667 - val_recall_3: 0.0153 - val_accuracy: 0.6106
# Epoch 31/300
# 209/209 [==============================] - 19s 89ms/step - loss: 0.6573 - precision_3: 0.6344 - recall_3: 0.0226 - accuracy: 0.6112 - val_loss: 0.6694 - val_precision_3: 0.5849 - val_recall_3: 0.0297 - val_accuracy: 0.6110
# Epoch 32/300
# 209/209 [==============================] - 19s 91ms/step - loss: 0.6577 - precision_3: 0.5620 - recall_3: 0.0295 - accuracy: 0.6100 - val_loss: 0.6654 - val_precision_3: 0.6129 - val_recall_3: 0.0182 - val_accuracy: 0.6102
# Epoch 33/300
# 209/209 [==============================] - 19s 90ms/step - loss: 0.6576 - precision_3: 0.6423 - recall_3: 0.0337 - accuracy: 0.6133 - val_loss: 0.6648 - val_precision_3: 0.6296 - val_recall_3: 0.0163 - val_accuracy: 0.6102
# 56/56 [==============================] - 1s 21ms/step - loss: 0.6640 - precision_3: 0.4780 - recall_3: 0.2023 - accuracy: 0.6002
# [[925 154]
#  [556 141]]
# Training took 628 seconds to complete.

# %%
seq_result # monitor val recall bidirectional
# Out:
# {12: [[0.6720257997512817,
#    0.498251736164093,
#    0.47342193126678467,
#    0.5660919547080994],
#   array([[503, 287],
#          [317, 285]])],
#  24: [[0.6715388298034668,
#    0.49162012338638306,
#    0.4012157917022705,
#    0.5802391171455383],
#   array([[658, 273],
#          [394, 264]])],
#  48: [[0.6704964637756348,
#    0.4724026024341583,
#    0.4229651093482971,
#    0.5797438621520996],
#   array([[705, 325],
#          [397, 291]])],
#  72: [[0.6639971137046814,
#    0.4779660999774933,
#    0.20229555666446686,
#    0.6002252101898193],
#   array([[925, 154],
#          [556, 141]])]}

# %% [markdown]
# # Model Architecture

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, 'statename_seq.png', show_shapes=True, show_layer_names=True)
