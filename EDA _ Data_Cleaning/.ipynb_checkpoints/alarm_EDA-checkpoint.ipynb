# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input, \
                                        BatchNormalization, Embedding, Masking,\
                                        Bidirectional, Conv1D, MaxPooling1D, Flatten, concatenate, MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import Model

from sklearn.utils import class_weight, shuffle
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.inspection import permutation_importance

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC
from xgboost import XGBRegressor, XGBClassifier
import lightgbm

import scipy.stats as stats
import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings("ignore")
BATCH_SIZE = 32
EPOCHS = 300

from datetime import datetime, timedelta, date
import pandas as pd
import numpy as np
import cx_Oracle
import pandas as pd
from sqlalchemy import create_engine
from imblearn.over_sampling import SMOTE
from collections import Counter
import joblib
import shap

# %%
def query_status(eq_id):
    try:
        oracle_string = "oracle+cx_oracle://{username}:{password}@{hostname}:{port}/{database}"
        engine = create_engine(
            oracle_string.format(
                username = 'TFM4CEBERUS',
                password = 'TFM4CEBERUS',
                hostname = 'ome-db.bth.infineon.com',
                port = '1538',
                database = 'ome'
                )
            )
    except Exception as e:
        print(str(e))

    query = f"""select EQ_ID, TIMESTAMP_START, TIMESTAMP_END, DURATION, STATE_NAME, LEVEL3_NAME, LEVEL3 
            from (SELECT
              eq.eq_id, eq.name, eq.eq_type_ident
            , data.timestamp_start,data.timestamp_end
            , ROUND((data.timestamp_end - data.timestamp_start)*24*60*60,0) AS Duration
            , data.tr25_3_status,data.tr25_4_status,data.tr25_5_status,data.eq_status
            , level5s.state_name
            , level5.state_name Level5_Name, level5.state_sign Level5
            , level4.state_name Level4_Name, level4.state_sign Level4
            , level3.state_name Level3_Name, level3.state_sign Level3
            ,mh.device
            ,mh.package,
            mh.lotid as lot,
            mh.product,
            mh.operation

            FROM OMEDATA.EQUIPMENT_STATE_HISTORY data
            , OMEADMIN.EQUIPMENT_INSTANCES eq
            , V_EQ_STATES level5s
            , OMEADMIN.DEF_STANDARD_STATEMODEL level5
            , OMEADMIN.DEF_STANDARD_STATEMODEL level4
            , OMEADMIN.DEF_STANDARD_STATEMODEL level3
            , OMEDATA.METAKEY_HISTORY mh

            WHERE data.eq_ident  = eq.eq_ident
            AND  data.eq_status = level5s.state_ident(+)
            AND level5.state_ident = data.tr25_5_status
            AND level4.state_ident = data.tr25_4_status
            AND level3.state_ident = data.tr25_3_status
            AND  data.metakey_ident =mh.ident(+)
            and data.timestamp_start > sysdate - 1050)
            where eq_id = '{eq_id}'
            and TIMESTAMP_START <= to_date('30/9/2021', 'dd/mm/yyyy')
            ORDER BY TIMESTAMP_START"""

    status = pd.read_sql(query, engine)
    status.columns = map(lambda x: str(x).upper(), status.columns) 

    return status

# %%
wba127_alarm = pd.read_excel("../Data/WBA127_FullAlarm.xlsx", usecols = "B,C,D,F,M")
wba127_status = query_status('WBA127')
# do not have to clean status data since the only information we need is that major down time

# %%
query_filter = (wba127_status.LEVEL3=='UDT') & (wba127_status.DURATION>=3600)
wba127_failure = wba127_status.loc[query_filter].reset_index(drop=True)

# %%
# drop rows with no alarm end time
# EDA suggests that there are rows with null values
wba127_alarm_n = wba127_alarm.loc[wba127_alarm.DT_CLEAR.notnull()].reset_index(drop=True)


##### FEATURE ENGINEERING: compute the time since last alarm #####
wba127_alarm_n['TIME SINCE LAST ALARM'] = (wba127_alarm_n['DT_SET'] - wba127_alarm_n['DT_SET'].shift(1)).dt.total_seconds()


##### Slice alarm table to make sure it is a subset of the status table #####
status_start = wba127_status.iloc[0]['TIMESTAMP_START']
query_filter = wba127_alarm_n.DT_SET > status_start
wba127_alarm_n = wba127_alarm_n[query_filter].reset_index(drop=True)


##### Calculate Time to Failure #####
failure_idx = 0
time_to_failure = []
for idx, row in wba127_alarm_n.iterrows():
    failure_time = wba127_failure.iloc[failure_idx]['TIMESTAMP_START']
    
    while row['DT_SET'] >= failure_time:
        failure_idx += 1
        failure_time = wba127_failure.iloc[failure_idx]['TIMESTAMP_START']

    ttf = (failure_time-row['DT_SET']).total_seconds()
    time_to_failure.append(ttf)

wba127_alarm_n['TTF'] = time_to_failure

# %%
##### Visualize TTF #####
date = wba127_alarm_n['DT_SET'].dt.date
ttf_y = wba127_alarm_n['TTF'].values

# notice that there is a long period of time with no alarm at all
plt.figure(figsize=(16,9))
plt.plot(date, ttf_y)
plt.show()

# %%
target = wba127_alarm_n['TTF']

lb = LabelEncoder()
enc_alarm = lb.fit_transform(wba127_alarm_n['Alarm ID'])
wba127_alarm_n['ENC ALARM'] = enc_alarm

features = ['ENC ALARM', 'TIME SINCE LAST ALARM']
df = wba127_alarm_n[features]

# %%
##### test train split #####
##### X_train contains 2 features, ENC ALarm and TIME SINCE LAST ALARM #####

train_idx = int(0.7*len(df))
val_idx = int(0.8*(len(df)))

X_train, y_train = df[:train_idx], target[:train_idx]
X_val, y_val = df[train_idx:val_idx], target[train_idx:val_idx]
X_test, y_test = df[val_idx:], target[val_idx:]

# %%
reg = lightgbm.LGBMRegressor(class_weight='balanced', random_state=42)
reg.fit(X_train, y_train,
       eval_set=[(X_val, y_val)],
       eval_metric='mae')

from sklearn.metrics import mean_squared_error

y_predicted = reg.predict(X_test)

rms = mean_squared_error(y_test, y_predicted, squared=True)
rms
# Out:
# [1]	valid_0's l1: 189376	valid_0's l2: 4.63092e+10
# [2]	valid_0's l1: 189823	valid_0's l2: 4.65451e+10
# [3]	valid_0's l1: 190275	valid_0's l2: 4.68223e+10
# [4]	valid_0's l1: 190805	valid_0's l2: 4.71326e+10
# [5]	valid_0's l1: 191344	valid_0's l2: 4.74972e+10
# [6]	valid_0's l1: 191857	valid_0's l2: 4.78305e+10
# [7]	valid_0's l1: 192308	valid_0's l2: 4.81436e+10
# [8]	valid_0's l1: 192858	valid_0's l2: 4.84854e+10
# [9]	valid_0's l1: 193365	valid_0's l2: 4.883e+10
# [10]	valid_0's l1: 193815	valid_0's l2: 4.91565e+10
# [11]	valid_0's l1: 194112	valid_0's l2: 4.94154e+10
# [12]	valid_0's l1: 194478	valid_0's l2: 4.97039e+10
# [13]	valid_0's l1: 194761	valid_0's l2: 4.99218e+10
# [14]	valid_0's l1: 195071	valid_0's l2: 5.01575e+10
# [15]	valid_0's l1: 195433	valid_0's l2: 5.04012e+10
# [16]	valid_0's l1: 195618	valid_0's l2: 5.05708e+10
# [17]	valid_0's l1: 195764	valid_0's l2: 5.07028e+10
# [18]	valid_0's l1: 195984	valid_0's l2: 5.08633e+10
# [19]	valid_0's l1: 196048	valid_0's l2: 5.09435e+10
# [20]	valid_0's l1: 195988	valid_0's l2: 5.09526e+10
# [21]	valid_0's l1: 196181	valid_0's l2: 5.11184e+10
# [22]	valid_0's l1: 196193	valid_0's l2: 5.11873e+10
# [23]	valid_0's l1: 196230	valid_0's l2: 5.12434e+10
# [24]	valid_0's l1: 196329	valid_0's l2: 5.13287e+10
# [25]	valid_0's l1: 196334	valid_0's l2: 5.1364e+10
# [26]	valid_0's l1: 196372	valid_0's l2: 5.14219e+10
# [27]	valid_0's l1: 196512	valid_0's l2: 5.1531e+10
# [28]	valid_0's l1: 196565	valid_0's l2: 5.15943e+10
# [29]	valid_0's l1: 196550	valid_0's l2: 5.16173e+10
# [30]	valid_0's l1: 196706	valid_0's l2: 5.17158e+10
# [31]	valid_0's l1: 196756	valid_0's l2: 5.17787e+10
# [32]	valid_0's l1: 196811	valid_0's l2: 5.18335e+10
# [33]	valid_0's l1: 196865	valid_0's l2: 5.19098e+10
# [34]	valid_0's l1: 196844	valid_0's l2: 5.19164e+10
# [35]	valid_0's l1: 196801	valid_0's l2: 5.19113e+10
# [36]	valid_0's l1: 196806	valid_0's l2: 5.19422e+10
# [37]	valid_0's l1: 196802	valid_0's l2: 5.1958e+10
# [38]	valid_0's l1: 196836	valid_0's l2: 5.19954e+10
# [39]	valid_0's l1: 196956	valid_0's l2: 5.20865e+10
# [40]	valid_0's l1: 196953	valid_0's l2: 5.21131e+10
# [41]	valid_0's l1: 196969	valid_0's l2: 5.21427e+10
# [42]	valid_0's l1: 197047	valid_0's l2: 5.21893e+10
# [43]	valid_0's l1: 197094	valid_0's l2: 5.22421e+10
# [44]	valid_0's l1: 197038	valid_0's l2: 5.22438e+10
# [45]	valid_0's l1: 197110	valid_0's l2: 5.22897e+10
# [46]	valid_0's l1: 197174	valid_0's l2: 5.23205e+10
# [47]	valid_0's l1: 197209	valid_0's l2: 5.23602e+10
# [48]	valid_0's l1: 197195	valid_0's l2: 5.23639e+10
# [49]	valid_0's l1: 197250	valid_0's l2: 5.23931e+10
# [50]	valid_0's l1: 197226	valid_0's l2: 5.23896e+10
# [51]	valid_0's l1: 197210	valid_0's l2: 5.23998e+10
# [52]	valid_0's l1: 197260	valid_0's l2: 5.24346e+10
# [53]	valid_0's l1: 197337	valid_0's l2: 5.24772e+10
# [54]	valid_0's l1: 197430	valid_0's l2: 5.25299e+10
# [55]	valid_0's l1: 197494	valid_0's l2: 5.25782e+10
# [56]	valid_0's l1: 197475	valid_0's l2: 5.25787e+10
# [57]	valid_0's l1: 197483	valid_0's l2: 5.25884e+10
# [58]	valid_0's l1: 197545	valid_0's l2: 5.26346e+10
# [59]	valid_0's l1: 197565	valid_0's l2: 5.26611e+10
# [60]	valid_0's l1: 197606	valid_0's l2: 5.27128e+10
# [61]	valid_0's l1: 197624	valid_0's l2: 5.27309e+10
# [62]	valid_0's l1: 197597	valid_0's l2: 5.2723e+10
# [63]	valid_0's l1: 197593	valid_0's l2: 5.27263e+10
# [64]	valid_0's l1: 197636	valid_0's l2: 5.27795e+10
# [65]	valid_0's l1: 197667	valid_0's l2: 5.28301e+10
# [66]	valid_0's l1: 197711	valid_0's l2: 5.28577e+10
# [67]	valid_0's l1: 197745	valid_0's l2: 5.2912e+10
# [68]	valid_0's l1: 197777	valid_0's l2: 5.29509e+10
# [69]	valid_0's l1: 197770	valid_0's l2: 5.29514e+10
# [70]	valid_0's l1: 197758	valid_0's l2: 5.29606e+10
# [71]	valid_0's l1: 197749	valid_0's l2: 5.29684e+10
# [72]	valid_0's l1: 197766	valid_0's l2: 5.29815e+10
# [73]	valid_0's l1: 197773	valid_0's l2: 5.30003e+10
# [74]	valid_0's l1: 197783	valid_0's l2: 5.30157e+10
# [75]	valid_0's l1: 197874	valid_0's l2: 5.30768e+10
# [76]	valid_0's l1: 197871	valid_0's l2: 5.30864e+10
# [77]	valid_0's l1: 197882	valid_0's l2: 5.31094e+10
# [78]	valid_0's l1: 197873	valid_0's l2: 5.31113e+10
# [79]	valid_0's l1: 197930	valid_0's l2: 5.31463e+10
# [80]	valid_0's l1: 197898	valid_0's l2: 5.31325e+10
# [81]	valid_0's l1: 197951	valid_0's l2: 5.31909e+10
# [82]	valid_0's l1: 197957	valid_0's l2: 5.31965e+10
# [83]	valid_0's l1: 197978	valid_0's l2: 5.32106e+10
# [84]	valid_0's l1: 197987	valid_0's l2: 5.32265e+10
# [85]	valid_0's l1: 197988	valid_0's l2: 5.32186e+10
# [86]	valid_0's l1: 198043	valid_0's l2: 5.32759e+10
# [87]	valid_0's l1: 198078	valid_0's l2: 5.33125e+10
# [88]	valid_0's l1: 198062	valid_0's l2: 5.33109e+10
# [89]	valid_0's l1: 198096	valid_0's l2: 5.33445e+10
# [90]	valid_0's l1: 198127	valid_0's l2: 5.33856e+10
# [91]	valid_0's l1: 198110	valid_0's l2: 5.33831e+10
# [92]	valid_0's l1: 198117	valid_0's l2: 5.33952e+10
# [93]	valid_0's l1: 198144	valid_0's l2: 5.34273e+10
# [94]	valid_0's l1: 198180	valid_0's l2: 5.34545e+10
# [95]	valid_0's l1: 198182	valid_0's l2: 5.34644e+10
# [96]	valid_0's l1: 198241	valid_0's l2: 5.3499e+10
# [97]	valid_0's l1: 198236	valid_0's l2: 5.35312e+10
# [98]	valid_0's l1: 198239	valid_0's l2: 5.35418e+10
# [99]	valid_0's l1: 198268	valid_0's l2: 5.35803e+10
# [100]	valid_0's l1: 198266	valid_0's l2: 5.35747e+10
# 62965469154.80716

# %%
x = range(len(y_test[:100]))
plt.figure(figsize=(16,9))
plt.plot(x, y_predicted[:100], color='red')
plt.plot(x, y_test[:100], color='blue')
plt.show()

# %%
# check for stationarity
from statsmodels.tsa.stattools import adfuller
y = target.values
result = adfuller(y)

# we notice that the p-value is much smaller than 0.05 meaning that TTF is stationary
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.733520
# p-value: 0.000000
# Critical Values:
# 	1%: -3.430
# 	5%: -2.862
# 	10%: -2.567

# %%
##### Check how many alarms happen on each month from 2018 #####

wba127_alarm_n['YEAR MONTH'] = wba127_alarm_n['DT_SET'].dt.strftime('%Y-%m')

freq_by_month = wba127_alarm_n.groupby(['YEAR MONTH']).size()

plt.plot(freq_by_month.index, freq_by_month.values)
plt.xticks(rotation=90)
plt.show()

# notice 2021-06 has the highest number of alarm occurence

# %%
##### Check alarm frequencies #####
wba127_alarm_n['Alarm ID'].value_counts()
# Out:
# 46     14102
# 45     11812
# 28      8562
# 44      5864
# 11      3742
# 24      3009
# 150     2058
# 23      1898
# 73      1840
# 33      1341
# 151      745
# 51       692
# 80       661
# 61       556
# 47       556
# 12       494
# 89       382
# 27       367
# 10       360
# 3        307
# 5        306
# 26       305
# 65       250
# 4        203
# 2        186
# 90       142
# 20       134
# 19        66
# 13        49
# 8         44
# 49        30
# 50        27
# 18        27
# 147       23
# 14        20
# 6         16
# 35        14
# 25        10
# 146        8
# 9          8
# 31         7
# 245        3
# 100        3
# 1          2
# 34         1
# Name: Alarm ID, dtype: int64

# %%
wba127_alarm_n.reset_index(drop=True, inplace=True)
wba127_alarm_n.loc[wba127_alarm_n['Alarm ID']==31]
# Out:
#       Equipment  Alarm ID              DT_SET            DT_CLEAR  DELTA_T  \
# 31080    WBA127        31 2020-06-30 15:18:52 2020-06-30 15:18:54        2
# 31081    WBA127        31 2020-06-30 15:20:06 2020-06-30 15:20:08        2
# 31082    WBA127        31 2020-06-30 15:20:13 2020-06-30 15:20:15        2
# 31083    WBA127        31 2020-06-30 15:20:17 2020-06-30 15:20:19        2
# 31084    WBA127        31 2020-06-30 15:20:39 2020-06-30 15:20:41        2
# 31085    WBA127        31 2020-06-30 15:31:44 2020-06-30 15:31:46        2
# 31086    WBA127        31 2020-06-30 15:32:25 2020-06-30 15:32:26        1
#
#        TIME SINCE LAST ALARM       TTF  ENC ALARM YEAR MONTH
# 31080                  267.0  112131.0         22    2020-06
# 31081                   74.0  112057.0         22    2020-06
# 31082                    7.0  112050.0         22    2020-06
# 31083                    4.0  112046.0         22    2020-06
# 31084                   22.0  112024.0         22    2020-06
# 31085                  665.0  111359.0         22    2020-06
# 31086                   41.0  111318.0         22    2020-06

# %%
store -r wba127_clean_status

# %%
# find out what is the EQ state name when the alarm happens
wba127_clean_status.head(50)
# Out:
#      EQ_ID     TIMESTAMP_START       TIMESTAMP_END  DURATION  \
# 0   WBA127 2018-12-05 12:58:08 2018-12-05 13:31:38    2010.0
# 1   WBA127 2018-12-05 13:31:38 2018-12-05 13:32:46      68.0
# 2   WBA127 2018-12-05 13:32:46 2018-12-05 13:32:53       7.0
# 3   WBA127 2018-12-05 13:32:53 2018-12-05 14:19:50    2817.0
# 4   WBA127 2018-12-05 14:19:50 2018-12-05 14:19:53       3.0
# 5   WBA127 2018-12-05 14:19:53 2018-12-05 15:32:25    4352.0
# 6   WBA127 2018-12-05 15:32:25 2018-12-05 15:32:36      11.0
# 7   WBA127 2018-12-05 15:32:36 2018-12-05 15:42:30     594.0
# 8   WBA127 2018-12-05 15:42:30 2018-12-05 15:56:28     838.0
# 9   WBA127 2018-12-05 15:56:28 2018-12-05 15:57:26      58.0
# 10  WBA127 2018-12-05 15:57:26 2018-12-05 15:58:04      38.0
# 11  WBA127 2018-12-05 15:58:04 2018-12-05 16:06:39     515.0
# 12  WBA127 2018-12-05 16:06:39 2018-12-05 16:41:22    2083.0
# 13  WBA127 2018-12-05 16:41:22 2018-12-05 16:42:15      53.0
# 14  WBA127 2018-12-05 16:42:15 2018-12-05 16:43:31      76.0
# 15  WBA127 2018-12-05 16:43:31 2018-12-05 17:23:02    2371.0
# 16  WBA127 2018-12-05 17:23:02 2018-12-05 17:24:32      90.0
# 17  WBA127 2018-12-05 17:24:32 2018-12-05 18:02:21    2269.0
# 18  WBA127 2018-12-05 18:02:21 2018-12-05 18:03:06      45.0
# 19  WBA127 2018-12-05 18:03:06 2018-12-05 18:06:32     206.0
# 20  WBA127 2018-12-05 18:06:32 2018-12-05 18:06:34       2.0
# 21  WBA127 2018-12-05 18:06:34 2018-12-05 18:54:55    2901.0
# 22  WBA127 2018-12-05 18:54:55 2018-12-05 18:55:48      53.0
# 23  WBA127 2018-12-05 18:55:48 2018-12-05 19:27:12    1884.0
# 24  WBA127 2018-12-05 19:27:12 2018-12-05 19:28:50      98.0
# 25  WBA127 2018-12-05 19:28:50 2018-12-05 20:16:03    2833.0
# 26  WBA127 2018-12-05 20:16:03 2018-12-05 20:22:05     362.0
# 27  WBA127 2018-12-05 20:22:05 2018-12-05 20:56:43    2078.0
# 28  WBA127 2018-12-05 20:56:43 2018-12-05 20:56:57      14.0
# 29  WBA127 2018-12-05 20:56:57 2018-12-05 20:58:01      64.0
# 30  WBA127 2018-12-05 20:58:01 2018-12-05 20:59:46     105.0
# 31  WBA127 2018-12-05 20:59:46 2018-12-05 21:56:49    3423.0
# 32  WBA127 2018-12-05 21:56:49 2018-12-05 21:56:52       3.0
# 33  WBA127 2018-12-05 21:56:52 2018-12-05 22:22:42    1550.0
# 34  WBA127 2018-12-05 22:22:42 2018-12-05 22:25:45     183.0
# 35  WBA127 2018-12-05 22:25:45 2018-12-05 22:26:56      71.0
# 36  WBA127 2018-12-05 22:26:56 2018-12-05 22:28:09      73.0
# 37  WBA127 2018-12-05 22:28:09 2018-12-05 23:08:21    2412.0
# 38  WBA127 2018-12-05 23:08:21 2018-12-05 23:10:20     119.0
# 39  WBA127 2018-12-05 23:10:20 2018-12-05 23:11:17      57.0
# 40  WBA127 2018-12-05 23:11:17 2018-12-05 23:12:29      72.0
# 41  WBA127 2018-12-05 23:12:29 2018-12-05 23:54:11    2502.0
# 42  WBA127 2018-12-05 23:54:11 2018-12-05 23:54:14       3.0
# 43  WBA127 2018-12-05 23:54:14 2018-12-05 23:55:25      71.0
# 44  WBA127 2018-12-05 23:55:25 2018-12-06 00:00:56     331.0
# 45  WBA127 2018-12-06 00:00:56 2018-12-06 00:28:50    1674.0
# 46  WBA127 2018-12-06 00:28:50 2018-12-06 00:29:05      15.0
# 47  WBA127 2018-12-06 00:29:05 2018-12-06 00:29:51      46.0
# 48  WBA127 2018-12-06 00:29:51 2018-12-06 00:32:24     153.0
# 49  WBA127 2018-12-06 00:32:24 2018-12-06 00:34:05     101.0
#
#               STATE_NAME            LEVEL3_NAME LEVEL3
# 0             PC Conform    Scheduled Down (SD)    SDT
# 1      Normal Production        Productive (PR)    PRD
# 2   Waiting For Response           Standby (SB)    SBY
# 3      Normal Production        Productive (PR)    PRD
# 4      Visual Inspection    Scheduled Down (SD)    SDT
# 5      Normal Production        Productive (PR)    PRD
# 6   Waiting For Response           Standby (SB)    SBY
# 7      Normal Production        Productive (PR)    PRD
# 8   Waiting For Response           Standby (SB)    SBY
# 9      Normal Production        Productive (PR)    PRD
# 10  Waiting For Response           Standby (SB)    SBY
# 11     Normal Production        Productive (PR)    PRD
# 12  Waiting For Response           Standby (SB)    SBY
# 13     Normal Production        Productive (PR)    PRD
# 14  Waiting For Response           Standby (SB)    SBY
# 15     Normal Production        Productive (PR)    PRD
# 16  Waiting For Response           Standby (SB)    SBY
# 17     Normal Production        Productive (PR)    PRD
# 18  Waiting For Response           Standby (SB)    SBY
# 19     Normal Production        Productive (PR)    PRD
# 20  Waiting For Response           Standby (SB)    SBY
# 21     Normal Production        Productive (PR)    PRD
# 22  Waiting For Response           Standby (SB)    SBY
# 23     Normal Production        Productive (PR)    PRD
# 24  Waiting For Operator  Unscheduled Down (UD)    UDT
# 25     Normal Production        Productive (PR)    PRD
# 26  Waiting For Response           Standby (SB)    SBY
# 27     Normal Production        Productive (PR)    PRD
# 28  Waiting For Response           Standby (SB)    SBY
# 29     Normal Production        Productive (PR)    PRD
# 30  Waiting For Response           Standby (SB)    SBY
# 31     Normal Production        Productive (PR)    PRD
# 32  Waiting For Response           Standby (SB)    SBY
# 33     Normal Production        Productive (PR)    PRD
# 34  Waiting For Response           Standby (SB)    SBY
# 35     Normal Production        Productive (PR)    PRD
# 36  Waiting For Response           Standby (SB)    SBY
# 37     Normal Production        Productive (PR)    PRD
# 38            SHORT TAIL  Unscheduled Down (UD)    UDT
# 39     Normal Production        Productive (PR)    PRD
# 40  Waiting For Response           Standby (SB)    SBY
# 41     Normal Production        Productive (PR)    PRD
# 42  Waiting For Response           Standby (SB)    SBY
# 43     Normal Production        Productive (PR)    PRD
# 44  Waiting For Response           Standby (SB)    SBY
# 45     Normal Production        Productive (PR)    PRD
# 46  Waiting For Response           Standby (SB)    SBY
# 47     Normal Production        Productive (PR)    PRD
# 48  Waiting For Response           Standby (SB)    SBY
# 49     Normal Production        Productive (PR)    PRD

# %%
# check what is the status of the machine at the start time of the alarm
# we want the status that starts at the alarm trigger, not the one ending (for alarm dt_set == state name end time)

LEVEL3 = []
STATE_NAME = []
STATE_DURATION = []

for idx, row in wba127_alarm_n.iterrows():
    alarm_start = row['DT_SET']
    query_filter = (wba127_clean_status['TIMESTAMP_START']<=alarm_start) & (wba127_clean_status['TIMESTAMP_END']>alarm_start)
    filtered = wba127_clean_status[query_filter]
    
    if len(filtered)>1:
        print(alarm_start, filtered)
        raise Exception('Multiple status within this time')
    elif len(filtered) == 0:
        LEVEL3.append(0)
        STATE_NAME.append(0)
        STATE_DURATION.append(0)
        continue
    
    LEVEL3.append(filtered.iloc[0]['LEVEL3'])
    STATE_NAME.append(filtered.iloc[0]['STATE_NAME'])
    STATE_DURATION.append(filtered.iloc[0]['DURATION'])

wba127_alarm_n['LEVEL3'] = LEVEL3
wba127_alarm_n['STATE_NAME'] = STATE_NAME
wba127_alarm_n['STATE NAME DURATION'] = STATE_DURATION

# %%
# inspect rows with 0 as level3
wba127_alarm_n[wba127_alarm_n['STATE_NAME']==0]

# 3 of them are all from 2019-02-13, this is the period where TFM database have no records, because of an exceptionally long PlanIdle
# Out:
#       Equipment  Alarm ID              DT_SET            DT_CLEAR  DELTA_T  \
# 169      WBA127        73 2018-12-10 21:03:41 2018-12-10 21:03:41        0
# 181      WBA127        73 2018-12-10 22:21:05 2018-12-10 22:21:05        0
# 868      WBA127        89 2018-12-22 13:05:52 2018-12-22 13:06:34       42
# 1355     WBA127        73 2019-01-02 15:06:04 2019-01-02 15:06:08        4
# 1781     WBA127        28 2019-01-11 08:47:27 2019-01-11 08:47:58       31
# ...         ...       ...                 ...                 ...      ...
# 60675    WBA127        28 2021-08-26 08:46:28 2021-08-26 08:46:29        1
# 60756    WBA127        28 2021-08-26 20:10:10 2021-08-26 20:10:12        2
# 60757    WBA127        28 2021-08-26 20:10:34 2021-08-26 20:10:37        3
# 60760    WBA127        28 2021-08-26 20:36:44 2021-08-26 20:36:47        3
# 60761    WBA127        28 2021-08-26 20:36:57 2021-08-26 20:36:59        2
#
#        TIME SINCE LAST ALARM        TTF  ENC ALARM YEAR MONTH LEVEL3  \
# 169                    136.0   169774.0         35    2018-12      0
# 181                    118.0   165130.0         35    2018-12      0
# 868                   1467.0  1737618.0         37    2018-12      0
# 1355                    11.0   780006.0         35    2019-01      0
# 1781                   275.0    25123.0         21    2019-01      0
# ...                      ...        ...        ...        ...    ...
# 60675                   11.0    34046.0         21    2021-08      0
# 60756                  134.0     8207.0         21    2021-08      0
# 60757                   24.0     8183.0         21    2021-08      0
# 60760                  931.0     6613.0         21    2021-08      0
# 60761                   13.0     6600.0         21    2021-08      0
#
#       STATE_NAME  STATE NAME DURATION
# 169            0                  0.0
# 181            0                  0.0
# 868            0                  0.0
# 1355           0                  0.0
# 1781           0                  0.0
# ...          ...                  ...
# 60675          0                  0.0
# 60756          0                  0.0
# 60757          0                  0.0
# 60760          0                  0.0
# 60761          0                  0.0
#
# [341 rows x 12 columns]

# %%
# remove rows with no state name and level3, make sure all those with 0 LEVEL3 has been removed by comparing against the above
wba127_alarm_n = wba127_alarm_n[~(wba127_alarm_n.LEVEL3==0)]
wba127_alarm_n['LEVEL3'].value_counts()
# Out:
# UDT    48909
# PRD     6021
# SDT     3861
# SBY     1660
# ENG      352
# NST       55
# EXC       33
# Name: LEVEL3, dtype: int64

# %%
wba127_alarm_n['Alarm ID'].value_counts()
# Out:
# 46     14100
# 45     11812
# 28      8367
# 44      5857
# 11      3726
# 24      2989
# 150     2051
# 23      1894
# 73      1806
# 33      1336
# 151      743
# 51       692
# 80       660
# 61       556
# 47       556
# 12       489
# 27       366
# 10       359
# 89       351
# 3        307
# 5        305
# 26       301
# 65       246
# 4        203
# 2        186
# 90       142
# 20       134
# 19        65
# 13        49
# 8         44
# 49        30
# 50        27
# 18        27
# 147       23
# 14        20
# 6         16
# 35        14
# 25        10
# 146        8
# 9          8
# 31         7
# 245        3
# 100        3
# 1          2
# 34         1
# Name: Alarm ID, dtype: int64

# %%
rare_alarms = [34, 1, 100, 245, 31, 9, 146]
wba127_alarm_n_r = wba127_alarm_n[~(wba127_alarm_n['Alarm ID'].isin(rare_alarms))]
# only removed 11 rows since the other alarms happen after 2020 May and we have sliced off the second part of the alarm

# %%
# label encode all categorical columns

wba127_alarm_n_r['ENC STATE_NAME'] = lb.fit_transform(wba127_alarm_n_r['STATE_NAME'])
wba127_alarm_n_r['ENC LEVEL3'] = lb.fit_transform(wba127_alarm_n_r['LEVEL3'])
wba127_alarm_n_r
# Out:
#       Equipment  Alarm ID              DT_SET            DT_CLEAR  DELTA_T  \
# 0        WBA127        46 2018-12-05 13:02:34 2018-12-05 13:02:40        6
# 1        WBA127        28 2018-12-05 13:03:01 2018-12-05 13:03:03        2
# 2        WBA127        11 2018-12-05 15:41:54 2018-12-05 15:56:19      865
# 3        WBA127        12 2018-12-05 18:01:40 2018-12-05 18:03:03       83
# 4        WBA127        28 2018-12-05 19:27:12 2018-12-05 19:27:15        3
# ...         ...       ...                 ...                 ...      ...
# 61227    WBA127        28 2021-08-30 23:54:33 2021-08-30 23:54:34        1
# 61228    WBA127        28 2021-08-30 23:54:48 2021-08-30 23:54:49        1
# 61229    WBA127        46 2021-08-30 23:55:04 2021-08-30 23:55:07        3
# 61230    WBA127        46 2021-08-30 23:56:00 2021-08-30 23:56:24       24
# 61231    WBA127        45 2021-08-30 23:57:16 2021-08-30 23:58:08       52
#
#        TIME SINCE LAST ALARM       TTF  ENC ALARM YEAR MONTH LEVEL3  \
# 0                     7004.0  428514.0         28    2018-12    SDT
# 1                       27.0  428487.0         21    2018-12    SDT
# 2                     9533.0  418954.0          9    2018-12    PRD
# 3                     8386.0  410568.0         10    2018-12    PRD
# 4                     5132.0  405436.0         21    2018-12    UDT
# ...                      ...       ...        ...        ...    ...
# 61227                   79.0   19855.0         21    2021-08    UDT
# 61228                   15.0   19840.0         21    2021-08    UDT
# 61229                   16.0   19824.0         28    2021-08    UDT
# 61230                   56.0   19768.0         28    2021-08    UDT
# 61231                   76.0   19692.0         27    2021-08    UDT
#
#                   STATE_NAME  STATE NAME DURATION  24 HOUR DOWN  \
# 0                 PC Conform               2010.0             0
# 1                 PC Conform               2010.0             0
# 2          Normal Production                594.0             0
# 3          Normal Production               2269.0             0
# 4       Waiting For Operator                 98.0             0
# ...                      ...                  ...           ...
# 61227   Waiting For Operator                 14.0             1
# 61228   Waiting For Operator                 13.0             1
# 61229             SHORT TAIL                 48.0             1
# 61230             SHORT TAIL                 56.0             1
# 61231  Non LIFTED STICK BOND                152.0             1
#
#        ENC STATE_NAME  ENC LEVEL3
# 0                  34           5
# 1                  34           5
# 2                  30           3
# 3                  30           3
# 4                  45           6
# ...               ...         ...
# 61227              45           6
# 61228              45           6
# 61229              38           6
# 61230              38           6
# 61231              28           6
#
# [60859 rows x 15 columns]

# %%
##### Compute major down for each alarm #####

# put equal sign on start and end time, just in case the alarm also marks the start of a major down

hour = 24
threshold = 3600

MAJOR_DOWN = []
for idx, row in wba127_alarm_n_r.iterrows():
    start = row['DT_SET']
    end = start+timedelta(hours=hour)
    frame = wba127_clean_status[(wba127_clean_status['TIMESTAMP_START']>=start) & \
                                 (wba127_clean_status['TIMESTAMP_START']<=end)]
    UD = frame.loc[frame['LEVEL3']=='UDT']

    if len(UD) == 0: #no record within this 6 hours:
        MAJOR_DOWN.append(0)
    else:
        time_diff = (UD['TIMESTAMP_END']-UD['TIMESTAMP_START']).dt.seconds
        if any(time_diff>=threshold): #threshold = 3600s
            MAJOR_DOWN.append(1)
        else:
            MAJOR_DOWN.append(0)

wba127_alarm_n_r['24 HOUR DOWN'] = MAJOR_DOWN

# %%
features = ['ENC ALARM', 'ENC STATE_NAME', 'ENC LEVEL3',
            'STATE NAME DURATION', 'TIME SINCE LAST ALARM']

df = wba127_alarm_n_r[features]
target = wba127_alarm_n_r['24 HOUR DOWN']

# %%
# the dataset that is being fed into the model
df
# Out:
#        ENC ALARM  ENC STATE_NAME  ENC LEVEL3  STATE NAME DURATION  \
# 0             28              34           5               2010.0
# 1             21              34           5               2010.0
# 2              9              30           3                594.0
# 3             10              30           3               2269.0
# 4             21              45           6                 98.0
# ...          ...             ...         ...                  ...
# 61227         21              45           6                 14.0
# 61228         21              45           6                 13.0
# 61229         28              38           6                 48.0
# 61230         28              38           6                 56.0
# 61231         27              28           6                152.0
#
#        TIME SINCE LAST ALARM
# 0                     7004.0
# 1                       27.0
# 2                     9533.0
# 3                     8386.0
# 4                     5132.0
# ...                      ...
# 61227                   79.0
# 61228                   15.0
# 61229                   16.0
# 61230                   56.0
# 61231                   76.0
#
# [60859 rows x 5 columns]

# %%
train_idx = int(0.7*len(df))
val_idx = int(0.8*(len(df)))

X_train, y_train = df[:train_idx], target[:train_idx]
X_val, y_val = df[train_idx:val_idx], target[train_idx:val_idx]
X_test, y_test = df[val_idx:], target[val_idx:]

clf = lightgbm.LGBMClassifier(
    boosting_type='gbdt',
    objective='binary',
    random_state=42,
    class_weight='balanced',
    reg_lambda=0.01
            )

clf.fit(X_train, y_train,
       eval_set=(X_val, y_val),
       eval_metric='auc',
        verbose=True)

pred = clf.predict(X_test)

confusion_matrix(y_test, pred), accuracy_score(y_test, pred)

# before introducing duration
# (array([[1745, 1475],
#         [ 951, 1193]]),
#  0.5477255779269202)

# after introducing duration
# (array([[1829, 1391],
#         [1058, 1086]]),
#  0.5434377330350485)
# Out:
# [1]	valid_0's auc: 0.559184	valid_0's binary_logloss: 0.6904
# [2]	valid_0's auc: 0.565515	valid_0's binary_logloss: 0.687768
# [3]	valid_0's auc: 0.565226	valid_0's binary_logloss: 0.686143
# [4]	valid_0's auc: 0.570143	valid_0's binary_logloss: 0.684315
# [5]	valid_0's auc: 0.566036	valid_0's binary_logloss: 0.683583
# [6]	valid_0's auc: 0.567253	valid_0's binary_logloss: 0.682454
# [7]	valid_0's auc: 0.565212	valid_0's binary_logloss: 0.68221
# [8]	valid_0's auc: 0.567046	valid_0's binary_logloss: 0.681894
# [9]	valid_0's auc: 0.567475	valid_0's binary_logloss: 0.681586
# [10]	valid_0's auc: 0.565816	valid_0's binary_logloss: 0.681417
# [11]	valid_0's auc: 0.566822	valid_0's binary_logloss: 0.680948
# [12]	valid_0's auc: 0.56529	valid_0's binary_logloss: 0.68095
# [13]	valid_0's auc: 0.564883	valid_0's binary_logloss: 0.680675
# [14]	valid_0's auc: 0.564468	valid_0's binary_logloss: 0.680909
# [15]	valid_0's auc: 0.564325	valid_0's binary_logloss: 0.681629
# [16]	valid_0's auc: 0.563644	valid_0's binary_logloss: 0.681798
# [17]	valid_0's auc: 0.562527	valid_0's binary_logloss: 0.682205
# [18]	valid_0's auc: 0.561326	valid_0's binary_logloss: 0.682365
# [19]	valid_0's auc: 0.560873	valid_0's binary_logloss: 0.682416
# [20]	valid_0's auc: 0.560366	valid_0's binary_logloss: 0.682895
# [21]	valid_0's auc: 0.560572	valid_0's binary_logloss: 0.683319
# [22]	valid_0's auc: 0.559506	valid_0's binary_logloss: 0.684082
# [23]	valid_0's auc: 0.559258	valid_0's binary_logloss: 0.684604
# [24]	valid_0's auc: 0.558793	valid_0's binary_logloss: 0.685188
# [25]	valid_0's auc: 0.556817	valid_0's binary_logloss: 0.685829
# [26]	valid_0's auc: 0.557946	valid_0's binary_logloss: 0.685185
# [27]	valid_0's auc: 0.557771	valid_0's binary_logloss: 0.685456
# [28]	valid_0's auc: 0.556766	valid_0's binary_logloss: 0.685839
# [29]	valid_0's auc: 0.556047	valid_0's binary_logloss: 0.686129
# [30]	valid_0's auc: 0.554999	valid_0's binary_logloss: 0.686072
# [31]	valid_0's auc: 0.554379	valid_0's binary_logloss: 0.686472
# [32]	valid_0's auc: 0.554137	valid_0's binary_logloss: 0.686539
# [33]	valid_0's auc: 0.553718	valid_0's binary_logloss: 0.687125
# [34]	valid_0's auc: 0.552955	valid_0's binary_logloss: 0.68787
# [35]	valid_0's auc: 0.551809	valid_0's binary_logloss: 0.688113
# [36]	valid_0's auc: 0.551426	valid_0's binary_logloss: 0.688352
# [37]	valid_0's auc: 0.551459	valid_0's binary_logloss: 0.688303
# [38]	valid_0's auc: 0.551019	valid_0's binary_logloss: 0.688578
# [39]	valid_0's auc: 0.551819	valid_0's binary_logloss: 0.688331
# [40]	valid_0's auc: 0.551147	valid_0's binary_logloss: 0.688673
# [41]	valid_0's auc: 0.55017	valid_0's binary_logloss: 0.689354
# [42]	valid_0's auc: 0.549992	valid_0's binary_logloss: 0.689903
# [43]	valid_0's auc: 0.549843	valid_0's binary_logloss: 0.689578
# [44]	valid_0's auc: 0.549934	valid_0's binary_logloss: 0.689874
# [45]	valid_0's auc: 0.549054	valid_0's binary_logloss: 0.690527
# [46]	valid_0's auc: 0.549369	valid_0's binary_logloss: 0.690773
# [47]	valid_0's auc: 0.549092	valid_0's binary_logloss: 0.691032
# [48]	valid_0's auc: 0.547698	valid_0's binary_logloss: 0.69184
# [49]	valid_0's auc: 0.548014	valid_0's binary_logloss: 0.6916
# [50]	valid_0's auc: 0.546973	valid_0's binary_logloss: 0.692044
# [51]	valid_0's auc: 0.546713	valid_0's binary_logloss: 0.692011
# [52]	valid_0's auc: 0.545959	valid_0's binary_logloss: 0.692351
# [53]	valid_0's auc: 0.54512	valid_0's binary_logloss: 0.692539
# [54]	valid_0's auc: 0.544241	valid_0's binary_logloss: 0.692498
# [55]	valid_0's auc: 0.544541	valid_0's binary_logloss: 0.692614
# [56]	valid_0's auc: 0.543764	valid_0's binary_logloss: 0.693052
# [57]	valid_0's auc: 0.543531	valid_0's binary_logloss: 0.692634
# [58]	valid_0's auc: 0.543276	valid_0's binary_logloss: 0.692671
# [59]	valid_0's auc: 0.542739	valid_0's binary_logloss: 0.693007
# [60]	valid_0's auc: 0.542728	valid_0's binary_logloss: 0.693028
# [61]	valid_0's auc: 0.542375	valid_0's binary_logloss: 0.692971
# [62]	valid_0's auc: 0.542838	valid_0's binary_logloss: 0.692397
# [63]	valid_0's auc: 0.54307	valid_0's binary_logloss: 0.692801
# [64]	valid_0's auc: 0.54327	valid_0's binary_logloss: 0.692874
# [65]	valid_0's auc: 0.543245	valid_0's binary_logloss: 0.692876
# [66]	valid_0's auc: 0.54236	valid_0's binary_logloss: 0.693158
# [67]	valid_0's auc: 0.542178	valid_0's binary_logloss: 0.693174
# [68]	valid_0's auc: 0.542014	valid_0's binary_logloss: 0.69334
# [69]	valid_0's auc: 0.541737	valid_0's binary_logloss: 0.693366
# [70]	valid_0's auc: 0.541512	valid_0's binary_logloss: 0.693803
# [71]	valid_0's auc: 0.541529	valid_0's binary_logloss: 0.693788
# [72]	valid_0's auc: 0.541744	valid_0's binary_logloss: 0.694202
# [73]	valid_0's auc: 0.541238	valid_0's binary_logloss: 0.694378
# [74]	valid_0's auc: 0.541191	valid_0's binary_logloss: 0.694348
# [75]	valid_0's auc: 0.541233	valid_0's binary_logloss: 0.694794
# [76]	valid_0's auc: 0.541648	valid_0's binary_logloss: 0.69447
# [77]	valid_0's auc: 0.541614	valid_0's binary_logloss: 0.694652
# [78]	valid_0's auc: 0.541197	valid_0's binary_logloss: 0.694874
# [79]	valid_0's auc: 0.540988	valid_0's binary_logloss: 0.694934
# [80]	valid_0's auc: 0.540722	valid_0's binary_logloss: 0.69517
# [81]	valid_0's auc: 0.540653	valid_0's binary_logloss: 0.695228
# [82]	valid_0's auc: 0.540473	valid_0's binary_logloss: 0.695375
# [83]	valid_0's auc: 0.540487	valid_0's binary_logloss: 0.695383
# [84]	valid_0's auc: 0.540254	valid_0's binary_logloss: 0.695257
# [85]	valid_0's auc: 0.539803	valid_0's binary_logloss: 0.695345
# [86]	valid_0's auc: 0.539498	valid_0's binary_logloss: 0.695541
# [87]	valid_0's auc: 0.53894	valid_0's binary_logloss: 0.695586
# [88]	valid_0's auc: 0.539094	valid_0's binary_logloss: 0.695912
# [89]	valid_0's auc: 0.538892	valid_0's binary_logloss: 0.696056
# [90]	valid_0's auc: 0.538341	valid_0's binary_logloss: 0.696049
# [91]	valid_0's auc: 0.538161	valid_0's binary_logloss: 0.696281
# [92]	valid_0's auc: 0.538344	valid_0's binary_logloss: 0.696461
# [93]	valid_0's auc: 0.537894	valid_0's binary_logloss: 0.696951
# [94]	valid_0's auc: 0.537616	valid_0's binary_logloss: 0.697281
# [95]	valid_0's auc: 0.537276	valid_0's binary_logloss: 0.697595
# [96]	valid_0's auc: 0.537452	valid_0's binary_logloss: 0.697545
# [97]	valid_0's auc: 0.537703	valid_0's binary_logloss: 0.69755
# [98]	valid_0's auc: 0.537846	valid_0's binary_logloss: 0.69752
# [99]	valid_0's auc: 0.537891	valid_0's binary_logloss: 0.697564
# [100]	valid_0's auc: 0.537274	valid_0's binary_logloss: 0.697814
# (array([[3099, 2292],
#         [3575, 3206]]),
#  0.5179921130463359)

# %%
# notice that 2020 Jan/ 2021 Apr and 2021 May suddenly has alot of alarms
# check whether are there more major down with the increase in alarms

any_month = wba127_alarm_n_r[wba127_alarm_n_r['YEAR MONTH']=='2019-08']
jan = wba127_alarm_n_r[wba127_alarm_n_r['YEAR MONTH']=='2020-01']
apr = wba127_alarm_n_r[wba127_alarm_n_r['YEAR MONTH']=='2021-04']
may =wba127_alarm_n_r[wba127_alarm_n_r['YEAR MONTH']=='2021-05']

any_month['24 HOUR DOWN'].value_counts(), jan['24 HOUR DOWN'].value_counts(), apr['24 HOUR DOWN'].value_counts(), may['24 HOUR DOWN'].value_counts()
# Out:
# (0    816
#  1    293
#  Name: 24 HOUR DOWN, dtype: int64,
#  0    1426
#  1     396
#  Name: 24 HOUR DOWN, dtype: int64,
#  0    1243
#  1    1057
#  Name: 24 HOUR DOWN, dtype: int64,
#  1    2120
#  0    1357
#  Name: 24 HOUR DOWN, dtype: int64)

# %%
features = ['ENC ALARM', 'ENC STATE_NAME', 'ENC LEVEL3',
            'STATE NAME DURATION', 'TIME SINCE LAST ALARM']

new_df = wba127_alarm_n_r[features]
target = wba127_alarm_n_r['24 HOUR DOWN']

##### Lag 
lags = [1,2,3,4,5]
for lag in lags:
    new_df[f'STATE NAME DURATION LAGGED {lag}'] = new_df['STATE NAME DURATION'].shift(lag)
    new_df[f'ENC STATE NAME LAGGED {lag}'] = new_df['ENC STATE_NAME'].shift(lag)
    new_df[f'ENC ALARM LAGGED {lag}'] = new_df['ENC ALARM'].shift(lag)
    new_df[f'ENC LEVEL3 LAGGED {lag}'] = new_df['ENC LEVEL3'].shift(lag)
    new_df[f'TIME SINCE LAST ALARM LAGGED {lag}'] = new_df['TIME SINCE LAST ALARM'].shift(lag)
    
##### Rolling aggregation of DURATION and TIME SINCE FAILURE #####
rolling = [5, 10, 15, 20]
for roll in rolling:
    new_df[f'STATE NAME DURATION ROLL {roll}'] = new_df['STATE NAME DURATION'].rolling(roll).mean()
    new_df[f'TIME SINCE LAST ALARM ROLL {roll}'] = new_df['TIME SINCE LAST ALARM'].rolling(roll).mean()

# %%
# convert ENC Alarm back to integer
categorical_columns = ['ENC STATE NAME LAGGED 1', 'ENC STATE NAME LAGGED 2', 'ENC STATE NAME LAGGED 3',\
                      'ENC STATE NAME LAGGED 4', 'ENC STATE NAME LAGGED 5', 'ENC ALARM LAGGED 1',\
                      'ENC ALARM LAGGED 2', 'ENC ALARM LAGGED 3', 'ENC ALARM LAGGED 4', 'ENC ALARM LAGGED 5',\
                      'ENC LEVEL3 LAGGED 1', 'ENC LEVEL3 LAGGED 2', 'ENC LEVEL3 LAGGED 3', 'ENC LEVEL3 LAGGED 4',\
                      'ENC LEVEL3 LAGGED 5']

# join two tables together to drop na
tmp_table = pd.concat([new_df, target], axis=1)
tmp_table = tmp_table.dropna()
tmp_table[categorical_columns] = tmp_table[categorical_columns].astype('int')


df = tmp_table.drop(['24 HOUR DOWN'], axis=1)
target = tmp_table['24 HOUR DOWN']

# %%
# how the training input looks like
df
# Out:
#        ENC ALARM  ENC STATE_NAME  ENC LEVEL3  STATE NAME DURATION  \
# 19             9              30           3               2036.0
# 20             9              30           3               2470.0
# 21            28              38           6                 67.0
# 22             9              30           3               3484.0
# 23            37              30           3                746.0
# ...          ...             ...         ...                  ...
# 61227         21              45           6                 14.0
# 61228         21              45           6                 13.0
# 61229         28              38           6                 48.0
# 61230         28              38           6                 56.0
# 61231         27              28           6                152.0
#
#        TIME SINCE LAST ALARM  STATE NAME DURATION LAGGED 1  \
# 19                    5115.0                        4140.0
# 20                    5990.0                        2036.0
# 21                    1508.0                        2470.0
# 22                    4030.0                          67.0
# 23                    9807.0                        3484.0
# ...                      ...                           ...
# 61227                   79.0                          79.0
# 61228                   15.0                          14.0
# 61229                   16.0                          13.0
# 61230                   56.0                          48.0
# 61231                   76.0                          56.0
#
#        ENC STATE NAME LAGGED 1  ENC ALARM LAGGED 1  ENC LEVEL3 LAGGED 1  \
# 19                          30                   9                    3
# 20                          30                   9                    3
# 21                          30                   9                    3
# 22                          38                  28                    6
# 23                          30                   9                    3
# ...                        ...                 ...                  ...
# 61227                       38                  28                    6
# 61228                       45                  21                    6
# 61229                       45                  21                    6
# 61230                       38                  28                    6
# 61231                       38                  28                    6
#
#        TIME SINCE LAST ALARM LAGGED 1  ...  ENC LEVEL3 LAGGED 5  \
# 19                             5292.0  ...                    3
# 20                             5115.0  ...                    3
# 21                             5990.0  ...                    3
# 22                             1508.0  ...                    3
# 23                             4030.0  ...                    3
# ...                               ...  ...                  ...
# 61227                           113.0  ...                    6
# 61228                            79.0  ...                    6
# 61229                            15.0  ...                    6
# 61230                            16.0  ...                    6
# 61231                            56.0  ...                    6
#
#        TIME SINCE LAST ALARM LAGGED 5  STATE NAME DURATION ROLL 5  \
# 19                             6093.0                      3513.4
# 20                             5016.0                      3008.0
# 21                             5380.0                      2720.0
# 22                             5475.0                      2439.4
# 23                             5292.0                      1760.6
# ...                               ...                         ...
# 61227                           206.0                        40.0
# 61228                            59.0                        39.8
# 61229                            17.0                        45.4
# 61230                           714.0                        42.0
# 61231                           113.0                        56.6
#
#        TIME SINCE LAST ALARM ROLL 5  STATE NAME DURATION ROLL 10  \
# 19                           5255.6                       2284.2
# 20                           5450.4                       2529.5
# 21                           4676.0                       2427.6
# 22                           4387.0                       2774.1
# 23                           5290.0                       2735.6
# ...                             ...                          ...
# 61227                         196.4                         52.2
# 61228                         187.6                         52.1
# 61229                         187.4                         56.0
# 61230                          55.8                         58.1
# 61231                          48.4                         52.7
#
#        TIME SINCE LAST ALARM ROLL 10  STATE NAME DURATION ROLL 15  \
# 19                            4212.9                  1943.066667
# 20                            4806.4                  1969.200000
# 21                            4603.4                  1870.333333
# 22                            4993.5                  2094.666667
# 23                            5370.6                  1977.600000
# ...                              ...                          ...
# 61227                          291.4                   164.400000
# 61228                          129.3                   149.733333
# 61229                          129.4                   152.200000
# 61230                          133.9                   155.266667
# 61231                          135.1                   161.800000
#
#        TIME SINCE LAST ALARM ROLL 15  STATE NAME DURATION ROLL 20  \
# 19                       4045.200000                      1806.35
# 20                       4088.933333                      1829.35
# 21                       3845.466667                      1732.20
# 22                       3929.133333                      1876.70
# 23                       4402.000000                      1800.55
# ...                              ...                          ...
# 61227                     297.066667                       174.00
# 61228                     246.000000                       173.60
# 61229                     231.533333                       175.20
# 61230                     234.400000                       173.95
# 61231                     238.600000                       137.65
#
#        TIME SINCE LAST ALARM ROLL 20
# 19                           4538.00
# 20                           4487.30
# 21                           4561.35
# 22                           4286.20
# 23                           4357.25
# ...                              ...
# 61227                         287.95
# 61228                         287.60
# 61229                         287.15
# 61230                         287.00
# 61231                         244.35
#
# [60840 rows x 38 columns]

# %%
train_idx = int(0.7*len(df))
val_idx = int(0.8*(len(df)))

X_train, y_train = df[:train_idx], target[:train_idx]
X_val, y_val = df[train_idx:val_idx], target[train_idx:val_idx]
X_test, y_test = df[val_idx:], target[val_idx:]

clf = lightgbm.LGBMClassifier(
    boosting_type='dart',
    objective='binary',
    random_state=42,
    class_weight='balanced',
    early_stopping_rounds=15,
    num_leaves=50,
    learning_rate=0.05,
    lambda_l2=0.01,
            )

clf.fit(X_train, y_train,
       eval_set=(X_val, y_val),
       eval_metric='auc',
        verbose=True)

pred = clf.predict(X_test)

confusion_matrix(y_test, pred), accuracy_score(y_test, pred)

# without adjusting num leaves
# (array([[1999, 1217],
#         [1007, 1137]]),
#  0.5850746268656717)
# Out:
# [LightGBM] [Warning] early_stopping_round is set=15, early_stopping_rounds=15 will be ignored. Current value: early_stopping_round=15
# [LightGBM] [Warning] lambda_l2 is set=0.01, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01
# [1]	valid_0's auc: 0.573702	valid_0's binary_logloss: 0.69197
# [2]	valid_0's auc: 0.583111	valid_0's binary_logloss: 0.691108
# [3]	valid_0's auc: 0.580114	valid_0's binary_logloss: 0.690541
# [4]	valid_0's auc: 0.581013	valid_0's binary_logloss: 0.689925
# [5]	valid_0's auc: 0.583496	valid_0's binary_logloss: 0.689228
# [6]	valid_0's auc: 0.584068	valid_0's binary_logloss: 0.688695
# [7]	valid_0's auc: 0.584408	valid_0's binary_logloss: 0.688583
# [8]	valid_0's auc: 0.584947	valid_0's binary_logloss: 0.688403
# [9]	valid_0's auc: 0.58736	valid_0's binary_logloss: 0.687709
# [10]	valid_0's auc: 0.587283	valid_0's binary_logloss: 0.687673
# [11]	valid_0's auc: 0.586692	valid_0's binary_logloss: 0.687869
# [12]	valid_0's auc: 0.587033	valid_0's binary_logloss: 0.687841
# [13]	valid_0's auc: 0.58837	valid_0's binary_logloss: 0.687474
# [14]	valid_0's auc: 0.587499	valid_0's binary_logloss: 0.687365
# [15]	valid_0's auc: 0.588825	valid_0's binary_logloss: 0.686516
# [16]	valid_0's auc: 0.588847	valid_0's binary_logloss: 0.686299
# [17]	valid_0's auc: 0.588865	valid_0's binary_logloss: 0.686308
# [18]	valid_0's auc: 0.588255	valid_0's binary_logloss: 0.686312
# [19]	valid_0's auc: 0.589027	valid_0's binary_logloss: 0.686022
# [20]	valid_0's auc: 0.589607	valid_0's binary_logloss: 0.685818
# [21]	valid_0's auc: 0.589036	valid_0's binary_logloss: 0.685867
# [22]	valid_0's auc: 0.589374	valid_0's binary_logloss: 0.685812
# [23]	valid_0's auc: 0.589377	valid_0's binary_logloss: 0.685383
# [24]	valid_0's auc: 0.589846	valid_0's binary_logloss: 0.685283
# [25]	valid_0's auc: 0.589321	valid_0's binary_logloss: 0.685301
# [26]	valid_0's auc: 0.58892	valid_0's binary_logloss: 0.685195
# [27]	valid_0's auc: 0.590163	valid_0's binary_logloss: 0.684742
# [28]	valid_0's auc: 0.590147	valid_0's binary_logloss: 0.684738
# [29]	valid_0's auc: 0.589852	valid_0's binary_logloss: 0.684753
# [30]	valid_0's auc: 0.592142	valid_0's binary_logloss: 0.684594
# [31]	valid_0's auc: 0.59298	valid_0's binary_logloss: 0.684456
# [32]	valid_0's auc: 0.593138	valid_0's binary_logloss: 0.684641
# [33]	valid_0's auc: 0.59182	valid_0's binary_logloss: 0.68505
# [34]	valid_0's auc: 0.592157	valid_0's binary_logloss: 0.684956
# [35]	valid_0's auc: 0.592653	valid_0's binary_logloss: 0.685073
# [36]	valid_0's auc: 0.592037	valid_0's binary_logloss: 0.684945
# [37]	valid_0's auc: 0.592221	valid_0's binary_logloss: 0.685045
# [38]	valid_0's auc: 0.592201	valid_0's binary_logloss: 0.685026
# [39]	valid_0's auc: 0.591085	valid_0's binary_logloss: 0.685298
# [40]	valid_0's auc: 0.593173	valid_0's binary_logloss: 0.684685
# [41]	valid_0's auc: 0.593136	valid_0's binary_logloss: 0.684675
# [42]	valid_0's auc: 0.593479	valid_0's binary_logloss: 0.684548
# [43]	valid_0's auc: 0.592537	valid_0's binary_logloss: 0.684842
# [44]	valid_0's auc: 0.593703	valid_0's binary_logloss: 0.684299
# [45]	valid_0's auc: 0.593597	valid_0's binary_logloss: 0.684126
# [46]	valid_0's auc: 0.593463	valid_0's binary_logloss: 0.68415
# [47]	valid_0's auc: 0.591737	valid_0's binary_logloss: 0.684736
# [48]	valid_0's auc: 0.591604	valid_0's binary_logloss: 0.684697
# [49]	valid_0's auc: 0.591356	valid_0's binary_logloss: 0.684689
# [50]	valid_0's auc: 0.591216	valid_0's binary_logloss: 0.684507
# [51]	valid_0's auc: 0.591197	valid_0's binary_logloss: 0.684478
# [52]	valid_0's auc: 0.591547	valid_0's binary_logloss: 0.684339
# [53]	valid_0's auc: 0.591401	valid_0's binary_logloss: 0.684429
# [54]	valid_0's auc: 0.590193	valid_0's binary_logloss: 0.684866
# [55]	valid_0's auc: 0.590451	valid_0's binary_logloss: 0.68467
# [56]	valid_0's auc: 0.58973	valid_0's binary_logloss: 0.68517
# [57]	valid_0's auc: 0.590171	valid_0's binary_logloss: 0.684641
# [58]	valid_0's auc: 0.590652	valid_0's binary_logloss: 0.684587
# [59]	valid_0's auc: 0.59059	valid_0's binary_logloss: 0.684567
# [60]	valid_0's auc: 0.59098	valid_0's binary_logloss: 0.684129
# [61]	valid_0's auc: 0.591325	valid_0's binary_logloss: 0.683988
# [62]	valid_0's auc: 0.589529	valid_0's binary_logloss: 0.684604
# [63]	valid_0's auc: 0.589864	valid_0's binary_logloss: 0.684438
# [64]	valid_0's auc: 0.58962	valid_0's binary_logloss: 0.68443
# [65]	valid_0's auc: 0.589323	valid_0's binary_logloss: 0.684445
# [66]	valid_0's auc: 0.588424	valid_0's binary_logloss: 0.684819
# [67]	valid_0's auc: 0.588762	valid_0's binary_logloss: 0.684741
# [68]	valid_0's auc: 0.589301	valid_0's binary_logloss: 0.684675
# [69]	valid_0's auc: 0.589719	valid_0's binary_logloss: 0.684876
# [70]	valid_0's auc: 0.589491	valid_0's binary_logloss: 0.684922
# [71]	valid_0's auc: 0.589873	valid_0's binary_logloss: 0.684809
# [72]	valid_0's auc: 0.589084	valid_0's binary_logloss: 0.684593
# [73]	valid_0's auc: 0.58909	valid_0's binary_logloss: 0.684733
# [74]	valid_0's auc: 0.589116	valid_0's binary_logloss: 0.68472
# [75]	valid_0's auc: 0.5901	valid_0's binary_logloss: 0.684148
# [76]	valid_0's auc: 0.5899	valid_0's binary_logloss: 0.684178
# [77]	valid_0's auc: 0.590586	valid_0's binary_logloss: 0.683924
# [78]	valid_0's auc: 0.590897	valid_0's binary_logloss: 0.683878
# [79]	valid_0's auc: 0.590973	valid_0's binary_logloss: 0.683832
# [80]	valid_0's auc: 0.591017	valid_0's binary_logloss: 0.683756
# [81]	valid_0's auc: 0.592237	valid_0's binary_logloss: 0.68348
# [82]	valid_0's auc: 0.591638	valid_0's binary_logloss: 0.684059
# [83]	valid_0's auc: 0.591807	valid_0's binary_logloss: 0.683996
# [84]	valid_0's auc: 0.589999	valid_0's binary_logloss: 0.684305
# [85]	valid_0's auc: 0.589957	valid_0's binary_logloss: 0.684345
# [86]	valid_0's auc: 0.589878	valid_0's binary_logloss: 0.684394
# [87]	valid_0's auc: 0.589685	valid_0's binary_logloss: 0.68385
# [88]	valid_0's auc: 0.589687	valid_0's binary_logloss: 0.683787
# [89]	valid_0's auc: 0.58955	valid_0's binary_logloss: 0.683771
# [90]	valid_0's auc: 0.589629	valid_0's binary_logloss: 0.683737
# [91]	valid_0's auc: 0.589748	valid_0's binary_logloss: 0.683769
# [92]	valid_0's auc: 0.58941	valid_0's binary_logloss: 0.683797
# [93]	valid_0's auc: 0.590877	valid_0's binary_logloss: 0.683423
# [94]	valid_0's auc: 0.591133	valid_0's binary_logloss: 0.683402
# [95]	valid_0's auc: 0.590693	valid_0's binary_logloss: 0.683601
# [96]	valid_0's auc: 0.589301	valid_0's binary_logloss: 0.68423
# [97]	valid_0's auc: 0.588705	valid_0's binary_logloss: 0.684279
# [98]	valid_0's auc: 0.588476	valid_0's binary_logloss: 0.684232
# [99]	valid_0's auc: 0.588483	valid_0's binary_logloss: 0.684145
# [100]	valid_0's auc: 0.588562	valid_0's binary_logloss: 0.684083
# (array([[2949, 2438],
#         [3105, 3676]]),
#  0.5444608809993425)

# %%
# (array([[2615, 1992],
#         [1238, 1474]]),
#  0.5586828801748873)

# small num leaves with dart
# (array([[2616, 1991],
#         [1162, 1550]]),
#  0.5692034430933187)

# gbdt
# (array([[2545, 2062],
#         [1107, 1605]]),
#  0.5670173520972811)

# %%
wba127_alarm_n_r
# Out:
#       Equipment  Alarm ID              DT_SET            DT_CLEAR  DELTA_T  \
# 0        WBA127        46 2018-12-05 13:02:34 2018-12-05 13:02:40        6
# 1        WBA127        28 2018-12-05 13:03:01 2018-12-05 13:03:03        2
# 2        WBA127        11 2018-12-05 15:41:54 2018-12-05 15:56:19      865
# 3        WBA127        12 2018-12-05 18:01:40 2018-12-05 18:03:03       83
# 4        WBA127        28 2018-12-05 19:27:12 2018-12-05 19:27:15        3
# ...         ...       ...                 ...                 ...      ...
# 61227    WBA127        28 2021-08-30 23:54:33 2021-08-30 23:54:34        1
# 61228    WBA127        28 2021-08-30 23:54:48 2021-08-30 23:54:49        1
# 61229    WBA127        46 2021-08-30 23:55:04 2021-08-30 23:55:07        3
# 61230    WBA127        46 2021-08-30 23:56:00 2021-08-30 23:56:24       24
# 61231    WBA127        45 2021-08-30 23:57:16 2021-08-30 23:58:08       52
#
#        TIME SINCE LAST ALARM       TTF  ENC ALARM YEAR MONTH LEVEL3  \
# 0                     7004.0  428514.0         28    2018-12    SDT
# 1                       27.0  428487.0         21    2018-12    SDT
# 2                     9533.0  418954.0          9    2018-12    PRD
# 3                     8386.0  410568.0         10    2018-12    PRD
# 4                     5132.0  405436.0         21    2018-12    UDT
# ...                      ...       ...        ...        ...    ...
# 61227                   79.0   19855.0         21    2021-08    UDT
# 61228                   15.0   19840.0         21    2021-08    UDT
# 61229                   16.0   19824.0         28    2021-08    UDT
# 61230                   56.0   19768.0         28    2021-08    UDT
# 61231                   76.0   19692.0         27    2021-08    UDT
#
#                   STATE_NAME  STATE NAME DURATION  24 HOUR DOWN  \
# 0                 PC Conform               2010.0             0
# 1                 PC Conform               2010.0             0
# 2          Normal Production                594.0             0
# 3          Normal Production               2269.0             0
# 4       Waiting For Operator                 98.0             0
# ...                      ...                  ...           ...
# 61227   Waiting For Operator                 14.0             1
# 61228   Waiting For Operator                 13.0             1
# 61229             SHORT TAIL                 48.0             1
# 61230             SHORT TAIL                 56.0             1
# 61231  Non LIFTED STICK BOND                152.0             1
#
#        ENC STATE_NAME  ENC LEVEL3
# 0                  34           5
# 1                  34           5
# 2                  30           3
# 3                  30           3
# 4                  45           6
# ...               ...         ...
# 61227              45           6
# 61228              45           6
# 61229              38           6
# 61230              38           6
# 61231              28           6
#
# [60859 rows x 15 columns]

# %%
## see if LGBM model is working fine by checking against the iris dataset

from sklearn import datasets

iris = datasets.load_iris()
df = iris.data[:,:4]
target = iris.target


df, target = shuffle(df, target)

train_idx = int(0.7*len(df))
val_idx = int(0.8*(len(df)))

X_train, y_train = df[:train_idx], target[:train_idx]
X_val, y_val = df[train_idx:val_idx], target[train_idx:val_idx]
X_test, y_test = df[val_idx:], target[val_idx:]

clf = lightgbm.LGBMClassifier(
    boosting_type='gbdt',
    objective='multiclass',
    random_state=42,
    lambda_l2=0.01,
            )

clf.fit(X_train, y_train,
       eval_set=(X_val, y_val),
        verbose=False)

pred = clf.predict(X_test)

confusion_matrix(y_test, pred), accuracy_score(y_test, pred)
# Out:
# [LightGBM] [Warning] lambda_l2 is set=0.01, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01
# (array([[ 8,  0,  0],
#         [ 0, 12,  0],
#         [ 0,  2,  8]]),
#  0.9333333333333333)
